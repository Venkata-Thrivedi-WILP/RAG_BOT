# %%
# Install required packages for the RAG system
# %pip install -q langchain-ollama langchain langchain-community faiss-cpu langchain_huggingface rank_bm25 gradio nest_asyncio markdown2 ipywidgets langchain_openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Chunks and Embedding loader

# %%
import pickle
import os
from typing import List
from langchain.schema import Document


def load_chunks_from_disk(chunks_path: str) -> List[Document]:
    """
    Load document chunks from disk.
    
    Args:
        chunks_path: Path to the saved chunks file
        
    Returns:
        List of document chunks
    """
    print(f"\nLoading chunks from {chunks_path}...")
    
    # Check if file exists
    if not os.path.exists(chunks_path):
        raise FileNotFoundError(f"Chunks file not found at {chunks_path}")
    
    # Load the chunks from disk
    with open(chunks_path, "rb") as f:
        chunks = pickle.load(f)
    
    print(f"Loaded {len(chunks)} chunks from disk")
    return chunks

# %%
# Initialize embedding model and load vector store
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Load embedding model
embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# Load pre-existing vector store
loaded_faiss_store = FAISS.load_local(
    "/workspaces/RAG_BOT/LocalEmbeddings/Chatgpt_Enriched_Full_Embedding",
    embedding_model,
    allow_dangerous_deserialization=True
)
print("FAISS vector store loaded successfully.")

# Load the chunks also
chunks = load_chunks_from_disk("/workspaces/RAG_BOT/LocalChunks/document_chunks_20250719_091443.pkl")
# Out:
# FAISS vector store loaded successfully.
#
# Loading chunks from /workspaces/RAG_BOT/LocalChunks/document_chunks_20250719_091443.pkl...
# Loaded 683 chunks from disk

# %% [markdown]
# ## LLM Configuration

# %%
# Initialize the LLM with rate limiting
from langchain_ollama import ChatOllama
from langchain_core.rate_limiters import InMemoryRateLimiter
from langchain_openai import ChatOpenAI
from getpass import getpass

# Configure rate limiting to prevent overloading the model
rate_limiter = InMemoryRateLimiter(
    requests_per_second=0.1,
    check_every_n_seconds=0.1,
    max_bucket_size=10,
)

openai_api_key = getpass("Enter your OpenAI API key: ")

# Initialize the LLM
llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    openai_api_key = openai_api_key,
    temperature=0.1,
    rate_limiter=rate_limiter
)

# %% [markdown]
# # RETRIEVAL METHODS

# %% [markdown]
# ## Retrival Method-1  ensemble

# %%
# Set up retrievers
from langchain.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever

# Extract documents from the docstore
try:
    all_docs = [loaded_faiss_store.docstore._dict[doc_id] for doc_id in loaded_faiss_store.index_to_docstore_id.values()]
except AttributeError:
    # Fallback for different docstore structure
    all_docs = [loaded_faiss_store.docstore.get(doc_id) for doc_id in loaded_faiss_store.index_to_docstore_id.values()]

# Configure different retrieval methods
bm25_retriever = BM25Retriever.from_documents(all_docs)
bm25_retriever.k = 2

# Vector similarity retrieval with MMR
mmr_retriever = loaded_faiss_store.as_retriever(search_type="mmr", search_kwargs={"k": 2})

# Vector similarity with score threshold
sst_retriever = loaded_faiss_store.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"score_threshold": 0.3, "k": 2}
)

# Create ensemble retriever combining multiple retrieval methods
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, mmr_retriever, sst_retriever],
    weights=[0.4, 0.3, 0.3]
)

# %%
# Set up prompt templates
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# Define system instructions for the model
SYSTEM_PROMPT = """
You are a highly knowledgeable and helpful CyberArk API documentation assistant. Your primary role is to answer developer questions accurately and clearly, *using only the provided API documentation context*.

**GENERAL RULES FOR ALL RESPONSES:**
1.  **Context Reliance:** Answer *ONLY* based on the provided "Documentation Context". Do not use external knowledge or invent information.
2.  **Handling Missing Information:** If the answer to the user's question is not explicitly found within the provided documentation context, politely state: "I don't have that specific information in the documentation I can access." Do NOT guess or invent details.
3.  **Markdown Formatting:** Always use Markdown for structuring your answers (headers, code blocks, bullet points, etc.) to enhance readability.


**SPECIFIC RESPONSE BEHAVIORS:**

* **IF the user input is a general greeting (e.g., "hello", "hi", "hey"):**
    * Respond politely as a friendly assistant.
    * Example: "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"

* **ELSE IF the user is asking about a specific API endpoint:**
    * Provide detailed endpoint information. This should include:
        * Path and HTTP method (GET, POST, PUT, DELETE)
        * Required parameters (query, path, body)
        * Security requirements
        * Request body schema (in JSON if available)
        * Response body schema (in JSON if available)
        * Any available sample requests and responses.
    * Format your response with markdown, using headers for sections and code blocks for JSON examples.

* **ELSE IF the user is asking a general question about CyberArk API functionality (not tied to a single endpoint):**
    * Answer based ONLY on the provided context.
    * Try to be clear, concise, informative and straight to the point.
    * Include relevant code examples only if it is asked in query.

* **ELSE IF the Documentation Context is not available or question is outside the scope of CyberArk API documentation:**
    * Politely state: "I'm specialized in CyberArk API documentation. I don't have information about that topic in my knowledge base."
"""


system_message = SystemMessagePromptTemplate.from_template(SYSTEM_PROMPT)

# Define how user questions and context are formatted
human_message = HumanMessagePromptTemplate.from_template(
    """
You are answering questions about CyberArk's API. Use the documentation context

Documentation Context:
----------------------
{context}

New User Question:
----------------------
{question}
"""
)

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from typing import List, Tuple, Optional
import time

def get_answer(query: str):
    
    # Skip retrieval for simple greetings
    greeting_terms = ["hello", "hi", "hey", "greetings"]
    is_greeting = any(term in query.lower() for term in greeting_terms) and len(query.split()) < 4
    
    if is_greeting:
        # Direct response for greetings without using retrieval
        response = "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"
    else:
        # Create a retrieval chain that combines context and chat history
        retrieval_chain = RunnableParallel(
            {"context": ensemble_retriever, "question": RunnablePassthrough()}
        )
        
        # Execute retrieval
        retrieval_output = retrieval_chain.invoke(query)
        
        # Format the retrieved documents into a single context string
        context_docs = retrieval_output["context"]
        context_text = "\n\n".join([doc.page_content for doc in context_docs])
        
        # Create the complete prompt
        chat_prompt = ChatPromptTemplate.from_messages([
            system_message,
            HumanMessagePromptTemplate.from_template(
                """
                You are answering questions about CyberArk's API. Use the documentation context

                Documentation Context:
                ----------------------
                {context}

                New User Question:
                ----------------------
                {question}
                """
            )
        ])
        
        # Create and execute the generation chain
        generation_chain = chat_prompt | llm
        
        # Add rate limiting to prevent API overload
        time.sleep(0.5)  # Simple rate limiting
        
        # Generate response
        response = generation_chain.invoke({
            "context": context_text,
            "question": query
        })
        
        # Extract the content from the response
        if hasattr(response, 'content'):
            response = response.content
    
    return response

# %% [markdown]
# ## Retrieval Method-2 Neighbourhood Expansion

# %%
def find_common_documents(docs1, docs2):
    """
    Find common documents between two document arrays based on doc_index and chunk_index in metadata.
    If nothing is common, return the top document from each array.
    
    Args:
        docs1: First array of documents
        docs2: Second array of documents
        
    Returns:
        List of common documents or top documents if nothing in common
    """
    # Handle empty array scenarios
    if not docs1 and not docs2:
        return []
    if not docs1:
        return [docs2[0]] if docs2 else []
    if not docs2:
        return [docs1[0]] if docs1 else []
    
    # Create a set of (doc_index, chunk_index) tuples from the first array for faster lookups
    doc_identifiers = {(doc.metadata.get('doc_index'), doc.metadata.get('chunk_index')) 
                      for doc in docs1 
                      if 'doc_index' in doc.metadata and 'chunk_index' in doc.metadata}
    
    # Find common documents based on doc_index and chunk_index
    common_docs = [doc for doc in docs2 
                  if 'doc_index' in doc.metadata and 'chunk_index' in doc.metadata and
                  (doc.metadata.get('doc_index'), doc.metadata.get('chunk_index')) in doc_identifiers]
    
    # If no common documents, take top document from each array
    if not common_docs:
        return [docs1[0], docs2[0]]
    
    return common_docs

# %%
from typing import List, Dict, Any

def get_adjacent_docs(chunks: List[Document], doc_index: int, chunk_index_in_doc: int, doc_name: str, n: int = 1, debug = False) -> Dict[str, Any]:
    """
    Get a specific chunk and its adjacent chunks within the same document.
    
    Args:
        chunks: List of all document chunks
        doc_index: Index of the document
        chunk_index_in_doc: Index of the chunk within the document
        n: Number of adjacent chunks to retrieve in each direction (default: 1)
    
    Returns:
        Dictionary containing the current chunk and lists of previous and next chunks
    """
    # Find all chunks from the specified document
    doc_chunks = [
        chunk for chunk in chunks 
        if chunk.metadata.get("doc_index") == doc_index and
        chunk.metadata.get("doc_name") == doc_name
    ]
    
    if not doc_chunks:
        raise ValueError(f"No chunks found for document index {doc_index}")
    
    # Sort chunks by their position in the document
    doc_chunks.sort(key=lambda x: x.metadata.get("chunk_index"))
    
    # Find the specified chunk within the document chunks
    target_chunk = None
    current_position = -1
    
    for i, chunk in enumerate(doc_chunks):
        if chunk.metadata.get("chunk_index") == chunk_index_in_doc:
            target_chunk = chunk
            current_position = i
            break
    
    if current_position == -1:
        raise ValueError(f"Chunk with index {chunk_index_in_doc} not found in document {doc_index}")
    
    if debug:
        print(f"\nRetrieving adjacent chunks for document {doc_index}:")
        print(f"  Document name: {target_chunk.metadata.get('doc_name', 'Unknown')}")
        print(f"  Chunk position within document: {chunk_index_in_doc + 1} of {target_chunk.metadata.get('total_chunks_in_doc', 'Unknown')}")
        print(f"  Retrieving {n} chunks before and after")
    
    # Get previous n chunks (if available)
    prev_chunks = []
    start_idx = max(0, current_position - n)
    if start_idx < current_position:
        prev_chunks = doc_chunks[start_idx:current_position]
    
    # Get next n chunks (if available)
    next_chunks = []
    end_idx = min(len(doc_chunks), current_position + n + 1)
    if current_position + 1 < end_idx:
        next_chunks = doc_chunks[current_position + 1:end_idx]
    
    print(f"  Found {len(prev_chunks)} previous chunks and {len(next_chunks)} next chunks")
    
    return {
        "current_chunk": target_chunk,
        "prev_chunks": prev_chunks,
        "next_chunks": next_chunks,
        "all_doc_chunks": doc_chunks
    }

# %%
# Implement the neighborhood expansion retrieval method
def retrieve_docs_with_neighborhood_expansion(query):
    """
    Retrieve documents using both similarity and BM25 methods, then find common documents.
    This implements a form of 'neighborhood expansion' by combining multiple retrieval methods.
    
    Args:
        query: User query string
        
    Returns:
        List of relevant documents
    """

    # RETRIEVERS USED WITH THE FLOW
    similarity_docs = sst_retriever.invoke(query)
    bm25_docs = bm25_retriever.invoke(query)
    
    # Find common or top documents
    relevant_docs = find_common_documents(similarity_docs, bm25_docs)

    final_expanded_docs = []
    # Get the neighbourhood expansion
    if len(relevant_docs)>0:
        for doc in relevant_docs:
            chunk_index = doc.metadata.get('chunk_index')
            doc_index = doc.metadata.get('doc_index')
            doc_name = doc.metadata.get('doc_name')
            response = get_adjacent_docs(chunks, doc_index, chunk_index,doc_name, n=2)
            expanded_docs = response["prev_chunks"] + [response["current_chunk"]] + response["next_chunks"]
            final_expanded_docs.extend(expanded_docs) 
    return final_expanded_docs

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from typing import List, Tuple, Optional
import time
from IPython.display import display, Markdown, Latex


def get_answer_using_neighbourhood(query: str, debug=False):
    """
    Retrieve documents and generate a response with neighborhood expansion.
    
    Args:
        query: User question
        debug: Whether to print the final prompt for debugging (default: True)
        
    Returns:
        Response from the LLM
    """
    # Skip retrieval for simple greetings
    greeting_terms = ["hello", "hi", "hey", "greetings"]
    is_greeting = any(term in query.lower() for term in greeting_terms) and len(query.split()) < 4
    
    if is_greeting:
        # Direct response for greetings without using retrieval
        response = "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"
    else:
        # Format the retrieved documents into a single context string
        context_docs = retrieve_docs_with_neighborhood_expansion(query)
        context_text = "\n\n".join([doc.page_content for doc in context_docs])

        print(f"\nRetrieved {len(context_docs)} relevant documents for the query: '{query}'")
        
        # Create the complete prompt
        chat_prompt = ChatPromptTemplate.from_messages([
            system_message,
            HumanMessagePromptTemplate.from_template(
            """
            You are answering questions about CyberArk's API. Use the documentation context

            Documentation Context:
            ----------------------
            {context}

            New User Question:
            ----------------------
            {question}
            """
            )
        ])
        
        ######################## ONLY FOR DEBUGGING #######################################
        # Format the prompt with actual values to print it
        if debug:
            # Get the messages with variables filled in
            formatted_messages = chat_prompt.format_messages(
                context=context_text,
                question=query
            )
            
            # Print the complete formatted prompt 
            print("\n===== FINAL PROMPT SENT TO LLM =====")
            for i, message in enumerate(formatted_messages):
                role = message.type
                content = message.content
                print(f"\n--- Message {i+1} ({role}) ---")
                print(content)
            print("\n====================================")
        
        # Create and execute the generation chain
        generation_chain = chat_prompt | llm
        
        # Add rate limiting to prevent API overload
        time.sleep(0.5)  # Simple rate limiting
        
        # Generate response
        response = generation_chain.invoke({
            "context": context_text,
            "question": query
        })
        
        # Extract the content from the response
        if hasattr(response, 'content'):
            response = response.content
    
    return response

# %% [markdown]
# ## Retrieval Method-3 Multiple Query Generation + BERT-Reranking Retriever

# %%
def get_descriptions_with_keyword_matching(query):
    """
    Retrieve keyword matching documents using BM25 and find their one-liner descriptions.
    
    Args:
        query: User query string
        
    Returns:
        Formatted string with category headers and one-liner descriptions
    """
    # 1. Retrieve documents using BM25 retriever
    retrieved_docs = bm25_retriever.invoke(query)
    
    # 2. Get top 2 documents
    top_docs = retrieved_docs[:2] if len(retrieved_docs) >= 2 else retrieved_docs
    
    # 3. Load OneLiners.json
    import json
    with open("/workspaces/RAG_BOT/Truths/OneLiners.json", "r") as f:
        one_liners_by_category = json.load(f)
    
    # 4. Process each document and find matching one-liners
    categories_found = []
    for doc in top_docs:
        # Extract category from doc_name
        category = "Unknown"
        
        if 'doc_name' in doc.metadata:
            doc_name = doc.metadata['doc_name']
            # Split by underscore and take the first part as category
            parts = doc_name.split('_')
            if parts:
                category = parts[0]        
        
        categories_found.append(category)

    categories_found = list(set(categories_found))  # Remove duplicates

    # Build formatted results with category headers
    formatted_results = []
    for category in categories_found:
        # Add the category as a header
        formatted_results.append(f"## {category}")
        # Add each description on a new line
        formatted_results.extend(one_liners_by_category[category])
    
    return formatted_results

# Example usage
# results = get_descriptions_with_keyword_matching("How to delete a policy?")
# print("\n".join(results))

# %%
from langchain_core.prompts import PromptTemplate


def generate_subqueries(query: str):
    """
    Generate 2-3 subqueries from a user query using LLM to help with retrieval.
    
    Args:
        query: User query string
        
    Returns:
        List of subqueries (2-3 refined queries)
    """
    # Get API context from keyword matching
    api_context = get_descriptions_with_keyword_matching(query)
    api_context_text = "\n".join(api_context)
    
    # Create the prompt for the LLM
    subquery_prompt = PromptTemplate.from_template("""
    You are a helpful assistant working with CyberArk API documentation. Given a user's natural language query, your task is to break it down into smaller, API-relevant subqueries. These subqueries should help clarify what exact information or API functionality the user is asking about, based on the available API endpoints.

    ## This is a detailed breakdown of all the available endpoints use this a context:
    {api_context_text}

    ## Guidelines:
    - Return 2 to 3 **clear and atomic** subqueries.
    - Each subquery should help narrow down or clarify user intent.
    - Focus strictly on what's possible based on the API spec.
    - Include any possible synonyms or related terms.
    - Include common ways developers might phrase this question.
    - Optionally incorporate relevant concepts such as endpoint names, paths, HTTP methods, parameters, request or response schemas if they are likely relevant.

    ### User Query:
    {query}

    ### Output format:
    - You should output 2-3 subqueries with comma seperation.
    - Example Output Format: sub_query1, subquery2, subquery3                                        
    """)
    
      # Generate evaluation response
    generation_chain = subquery_prompt | llm
    subquery_response = generation_chain.invoke({
        "api_context_text": api_context_text,
        "query" : query
    })

    # Extract content if using ChatOpenAI
    if hasattr(subquery_response, 'content'):
        subquery_response = subquery_response.content
    
    
    # First, try splitting by comma
    subqueries = [sq.strip() for sq in subquery_response.split(',')]

    subqueries.append(query) # Ensure original query is included
    
    return subqueries

# k = generate_subqueries("how to delete a policy?")
# print(k)

# %%
def retrieve_documents_with_query_expansion(query: str, debug: bool = False):
    """
    Retrieve documents using query expansion and multiple retrievers.
    
    This method:
    1. Generates multiple subqueries from the user's query
    2. Retrieves documents for each subquery using BM25 and similarity search
    3. Combines all results and removes duplicates based on document metadata
    
    Args:
        query: The user's original query
        debug: Whether to print detailed debug information
        
    Returns:
        List of unique relevant documents
    """
    if debug:
        print(f"Processing query: '{query}'")
    
    # Generate subqueries
    subqueries = generate_subqueries(query)
    
    if debug:
        print(f"Generated {len(subqueries)} subqueries:")
        for i, subq in enumerate(subqueries):
            print(f"  {i+1}. {subq}")
    
    # Initialize empty list to collect all documents
    all_docs = []
    
    # Process each subquery
    for i, subquery in enumerate(subqueries):
        if debug:
            print(f"Processing subquery {i+1}/{len(subqueries)}: '{subquery}'")
        
        # Get documents from BM25 retriever
        bm25_docs = bm25_retriever.invoke(subquery)
        if debug:
            print(f"BM25 retriever found {len(bm25_docs)} documents")
        
        # Get documents from similarity search retriever
        sst_docs = sst_retriever.invoke(subquery)
        if debug:
            print(f"Similarity retriever found {len(sst_docs)} documents")
        
        # Add all retrieved documents to our collection
        all_docs.extend(bm25_docs)
        all_docs.extend(sst_docs)
    
    if debug:
        print(f"Total documents retrieved: {len(all_docs)} (before deduplication)")
    
    # Remove duplicates based on doc_index and chunk_index
    unique_docs = []
    seen_indices = set()
    
    for doc in all_docs:
        # Extract document and chunk indices
        doc_index = doc.metadata.get('doc_index')
        chunk_index = doc.metadata.get('chunk_index')
        
        # Skip documents without proper metadata
        if doc_index is None or chunk_index is None:
            if debug:
                print(f"Skipping document with missing metadata: {doc.metadata}")
            continue
        
        # Create a unique identifier for this document chunk
        doc_identifier = (doc_index, chunk_index)
        
        # Add to unique docs if we haven't seen it before
        if doc_identifier not in seen_indices:
            seen_indices.add(doc_identifier)
            unique_docs.append(doc)
    
    if debug:
        print(f"After deduplication: {len(unique_docs)} unique documents")
        if len(unique_docs) > 0:
            # Show some information about the first few documents
            print("Sample of retrieved documents:")
            for i, doc in enumerate(unique_docs):
                doc_name = doc.metadata.get('doc_name', 'Unknown')
                print(f"  Document {i+1}: {doc_name} (doc_index={doc.metadata.get('doc_index')}, chunk_index={doc.metadata.get('chunk_index')})")
                content_preview = doc.page_content[:100] + "..." if len(doc.page_content) > 100 else doc.page_content
                print(f"  Preview: {content_preview}\n")
    
    return unique_docs

# # Example usage
# docs = retrieve_with_query_expansion("How to delete a policy?", debug=True)
# docs

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
def get_bert_reordered_documents(query: str, debug: bool = False):
    """
    Retrieve and reorder documents using BERT embeddings to prioritize 
    by semantic similarity to the query. Only includes documents with
    similarity score > 0.2.
    
    Args:
        query: The user's query
        debug: Whether to print debug information
        
    Returns:
        List of documents reordered by relevance to the query with scores > 0.2
    """
    if debug:
        print(f"Processing query: '{query}'")
    
    # Get documents using query expansion
    retrieved_docs = retrieve_documents_with_query_expansion(query, debug=debug)
    
    if debug:
        print(f"Retrieved {len(retrieved_docs)} documents")
    
    if not retrieved_docs:
        return []
        
    # Initialize BERT model
    if debug:
        print("Loading BERT model for semantic reordering")
    model = SentenceTransformer('all-MiniLM-L6-v2')  # Using the same model as your embeddings
    
    # Extract document contents
    doc_texts = [doc.page_content for doc in retrieved_docs]
    
    # Compute embeddings
    if debug:
        print("Computing BERT embeddings for query and documents")
    query_embedding = model.encode([query])[0]
    doc_embeddings = model.encode(doc_texts)
    
    # Compute similarities
    similarities = []
    for i, doc_embedding in enumerate(doc_embeddings):
        similarity = np.dot(query_embedding, doc_embedding) / (
            np.linalg.norm(query_embedding) * np.linalg.norm(doc_embedding)
        )
        similarities.append((i, similarity))
    
    # Filter documents with similarity score above threshold (0.2)
    threshold = 0.2
    filtered_similarities = [(idx, score) for idx, score in similarities if score > threshold]
    
    if debug:
        print(f"Filtering documents with similarity score > {threshold}")
        print(f"Before filtering: {len(similarities)} documents")
        print(f"After filtering: {len(filtered_similarities)} documents")
    
    # Sort documents by similarity (highest first)
    filtered_similarities.sort(key=lambda x: x[1], reverse=True)
    
    # Reorder documents
    reordered_docs = [retrieved_docs[idx] for idx, _ in filtered_similarities]
    
    if debug:
        print("Documents reordered by semantic similarity to query")
        for i, (idx, score) in enumerate(filtered_similarities):
            doc = retrieved_docs[idx]
            print(f"  {i+1}. [{score:.4f}] {doc.metadata.get('doc_name', 'Unknown')}")
        
        if len(filtered_similarities) == 0:
            print("  No documents met the similarity threshold. Consider lowering the threshold.")
    
    return reordered_docs

# get_bert_reordered_documents("How to delete a policy?", debug=True)

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from typing import List, Tuple, Optional
import time
from IPython.display import display, Markdown, Latex


def get_answer_using_bert_based_reordering(query: str, debug=False):
    """
    Retrieve documents and generate a response with neighborhood expansion.
    
    Args:
        query: User question
        debug: Whether to print the final prompt for debugging (default: True)
        
    Returns:
        Response from the LLM
    """
    # Skip retrieval for simple greetings
    greeting_terms = ["hello", "hi", "hey", "greetings"]
    is_greeting = any(term in query.lower() for term in greeting_terms) and len(query.split()) < 4
    
    if is_greeting:
        # Direct response for greetings without using retrieval
        response = "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"
    else:
        # Format the retrieved documents into a single context string
        context_docs = get_bert_reordered_documents(query, debug)
        context_text = "\n\n".join([doc.page_content for doc in context_docs])

        print(f"\nRetrieved {len(context_docs)} relevant documents for the query: '{query}'")
        
        # Create the complete prompt
        chat_prompt = ChatPromptTemplate.from_messages([
            system_message,
            HumanMessagePromptTemplate.from_template(
            """
            You are answering questions about CyberArk's API. Use the documentation context

            Documentation Context:
            ----------------------
            {context}

            New User Question:
            ----------------------
            {question}
            """
            )
        ])
        
        ######################## ONLY FOR DEBUGGING #######################################
        # Format the prompt with actual values to print it
        if debug:
            # Get the messages with variables filled in
            formatted_messages = chat_prompt.format_messages(
                context=context_text,
                question=query
            )
            
            # Print the complete formatted prompt 
            print("\n===== FINAL PROMPT SENT TO LLM =====")
            for i, message in enumerate(formatted_messages):
                role = message.type
                content = message.content
                print(f"\n--- Message {i+1} ({role}) ---")
                print(content)
            print("\n====================================")
        
        # Create and execute the generation chain
        generation_chain = chat_prompt | llm
        
        # Add rate limiting to prevent API overload
        time.sleep(0.5)  # Simple rate limiting
        
        # Generate response
        response = generation_chain.invoke({
            "context": context_text,
            "question": query
        })
        
        # Extract the content from the response
        if hasattr(response, 'content'):
            response = response.content
    
    return response

# display(Markdown(get_answer_using_bert_based_reordering("How to delete a policy?", debug=True)))

# %% [markdown]
# ## Retrieval Method - 4  - Recursive Retrieval-Generation with Self-Correction

# %%
from langchain_core.prompts import PromptTemplate
import re


def identify_knowledge_gaps(query: str, initial_response: str):
    """
    Have the LLM identify knowledge gaps in its initial response.
    
    Args:
        query: The original user query
        initial_response: The first-pass response from the LLM
        
    Returns:
        List of follow-up queries to fill identified gaps
    """
    # Create the prompt for gap identification
    gap_prompt = PromptTemplate.from_template("""
    You are analyzing a response to a user question about the CyberArk API. Your goal is to identify any information gaps, 
    uncertainties, or areas where more specific details would improve the answer.
    
    Original Question: {query}
    
    Response to Analyze: {response}
    
    Think about:
    1. Missing technical details that would make the answer more complete
    2. Ambiguous statements that need clarification
    3. API parameters, options, or behaviors not fully explained
    4. Missing examples or use cases that would improve understanding
    5. Areas where the answer expresses uncertainty or lack of information
    
    For each gap you identify, formulate a specific follow-up query that would help retrieve the missing information.
    Return a list of 1-3 follow-up queries, formatted as a comma-separated list.
    
    If the response seems comprehensive and doesn't have significant gaps, return "COMPLETE".
    
    Follow-up Queries:
    """)
    
    # Generate the gap analysis
    generation_chain = gap_prompt | llm
    gap_response = generation_chain.invoke({
        "query": query,
        "response": initial_response
    })
    
    # Extract content if using ChatOpenAI
    if hasattr(gap_response, 'content'):
        gap_response = gap_response.content
    
    # If the LLM thinks the response is complete, return empty list
    if "COMPLETE" in gap_response:
        return []
    
    # Split the follow-up queries
    follow_up_queries = [q.strip() for q in gap_response.split(',')]
    return follow_up_queries

# %%
def get_answer_with_recursive_generation(query: str, debug=False):
    """
    Implement the recursive retrieval-generation technique.
    
    Args:
        query: User question
        debug: Whether to print debug information
        
    Returns:
        Enhanced response from the LLM
    """
    # Skip retrieval for simple greetings
    greeting_terms = ["hello", "hi", "hey", "greetings"]
    is_greeting = any(term in query.lower() for term in greeting_terms) and len(query.split()) < 4
    
    if is_greeting:
        return "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"
    
    # STEP 1: Initial retrieval using an existing method (choose the best one as base)
    # Let's use BERT reranking as our base method
    if debug:
        print(f"STEP 1: Initial retrieval for query: '{query}'")
    
    initial_docs = get_bert_reordered_documents(query, debug=debug)
    initial_context = "\n\n".join([doc.page_content for doc in initial_docs])
    
    if debug:
        print(f"Retrieved {len(initial_docs)} documents for initial context")
    
    # STEP 2: Generate initial response
    if debug:
        print("STEP 2: Generating initial response")
    
    chat_prompt = ChatPromptTemplate.from_messages([
        system_message,
        HumanMessagePromptTemplate.from_template(
        """
        You are answering questions about CyberArk's API. Use the documentation context

        Documentation Context:
        ----------------------
        {context}

        New User Question:
        ----------------------
        {question}
        """
        )
    ])
    
    generation_chain = chat_prompt | llm
    initial_response = generation_chain.invoke({
        "context": initial_context,
        "question": query
    })
    
    if hasattr(initial_response, 'content'):
        initial_response = initial_response.content
    
    # STEP 3: Identify knowledge gaps
    if debug:
        print("STEP 3: Analyzing initial response for knowledge gaps")
    
    follow_up_queries = identify_knowledge_gaps(query, initial_response)
    
    if not follow_up_queries:
        if debug:
            print("No knowledge gaps identified. Returning initial response.")
        return initial_response
    
    if debug:
        print(f"Identified {len(follow_up_queries)} knowledge gaps:")
        for i, fq in enumerate(follow_up_queries):
            print(f"  {i+1}. {fq}")
    
    # STEP 4: Retrieve additional context for follow-up queries
    if debug:
        print("STEP 4: Retrieving additional context for follow-up queries")
    
    additional_docs = []
    for follow_up in follow_up_queries:
        # Use a different retrieval method for diversity
        follow_up_docs = retrieve_docs_with_neighborhood_expansion(follow_up)
        additional_docs.extend(follow_up_docs)
    
    # Remove duplicates
    seen_indices = set()
    unique_additional_docs = []
    
    for doc in additional_docs:
        doc_index = doc.metadata.get('doc_index')
        chunk_index = doc.metadata.get('chunk_index')
        
        if doc_index is None or chunk_index is None:
            continue
        
        doc_identifier = (doc_index, chunk_index)
        
        if doc_identifier not in seen_indices:
            seen_indices.add(doc_identifier)
            unique_additional_docs.append(doc)
    
    if debug:
        print(f"Retrieved {len(unique_additional_docs)} additional documents")
    
    # STEP 5: Generate enhanced response with combined context
    if debug:
        print("STEP 5: Generating enhanced response with combined context")
    
    # Combine initial and additional context
    additional_context = "\n\n".join([doc.page_content for doc in unique_additional_docs])
    combined_context = f"{initial_context}\n\n{additional_context}"
    
    # Create prompt for final generation
    enhanced_prompt = ChatPromptTemplate.from_messages([
        system_message,
        HumanMessagePromptTemplate.from_template(
        """
        You are answering questions about CyberArk's API. Use the documentation context below.
        
        This context includes both initial information and additional details to provide a more complete answer.

        Documentation Context:
        ----------------------
        {context}

        User Question:
        ----------------------
        {question}
        
        Your previous response had some gaps or uncertainties. With the additional context, provide an enhanced, 
        more complete response that addresses those gaps while maintaining accuracy and clarity.
        """
        )
    ])
    
    # Generate enhanced response
    enhanced_generation_chain = enhanced_prompt | llm
    enhanced_response = enhanced_generation_chain.invoke({
        "context": combined_context,
        "question": query
    })
    
    if hasattr(enhanced_response, 'content'):
        enhanced_response = enhanced_response.content
    
    if debug:
        print("Recursive retrieval-generation complete")
    
    return enhanced_response

# %%
# get_answer_with_recursive_generation("How to delete a policy?", debug=True)

# %% [markdown]
# ## Retrieval Method - 5  : Dynamic Prompt Engineering Retrieval Method

# %%
import json
from langchain_core.prompts import PromptTemplate
def analyze_query_and_generate_prompts(query: str, debug: bool = False):
    """
    Use the LLM to analyze the query and generate tailored system and user prompts.
    
    Args:
        query: The user's question
        debug: Whether to print debug information
        
    Returns:
        Dictionary containing tailored system prompt and user message template
    """
    # Create the prompt analyzer template
    prompt_analyzer_template = PromptTemplate.from_template("""
    You are an expert in prompt engineering for large language models. Your task is to analyze a user query about the CyberArk API 
    and create the optimal system prompt and user message template to get the best possible response.
    
    ### User Query:
    {query}
    
    ### Analysis Instructions:
    1. Identify the query type (API endpoint details, general concept, troubleshooting, etc.)
    2. Determine what specific API documentation information would be most relevant
    3. Consider what specific formatting or structure would best present this information
    
    ### Output Format:
    Return a JSON object with two fields:
    1. "system_prompt": A tailored system prompt that gives the model specific instructions about how to handle this type of query
    2. "user_message_template": A template for structuring the user message with the context and query
    
    The system_prompt should provide specific instructions about:
    - How to structure the response for this query type
    - What details to prioritize and emphasize
    - Any specific formatting considerations (code blocks, tables, etc.)
    - How to handle potential ambiguities or limitations

    The user_message_template should include placeholders for {{context}} and {{question}}.

    Example output format:
    ```json
    {{
      "system_prompt": "You are a CyberArk API documentation expert...[detailed tailored instructions]...",
      "user_message_template": "Here is documentation about the CyberArk API:\\n\\nContext:\\n{{context}}\\n\\nUser Question:\\n{{question}}\\n\\nProvide a comprehensive answer focusing on..."
    }}
    ```
    """)
    
    # Generate the prompts
    generation_chain = prompt_analyzer_template | llm
    analyzer_response = generation_chain.invoke({"query": query})
    
    # Extract content if using ChatOpenAI
    if hasattr(analyzer_response, 'content'):
        analyzer_response = analyzer_response.content
    
    # Parse the JSON response
    try:
        # Remove markdown code block markers if present
        analyzer_response = analyzer_response.replace("```json", "").replace("```", "").strip()
        prompt_components = json.loads(analyzer_response)
        
        if debug:
            print("\n=== DYNAMICALLY GENERATED PROMPTS ===")
            print(f"\nSYSTEM PROMPT:\n{prompt_components['system_prompt']}")
            print(f"\nUSER MESSAGE TEMPLATE:\n{prompt_components['user_message_template']}")
            print("\n======================================")
        
        return prompt_components
    except json.JSONDecodeError as ex:
        print(f"Error parsing prompt components: {ex}")
        print(f"Raw response: {analyzer_response}")
        raise ex

# %%
def get_answer_with_dynamic_prompting(query: str, debug: bool = False):
    """
    Generate answers using dynamically generated prompts tailored to the query.
    
    Args:
        query: The user's question
        debug: Whether to print debug information
        
    Returns:
        Response from the LLM
    """
    # Skip retrieval for simple greetings
    greeting_terms = ["hello", "hi", "hey", "greetings"]
    is_greeting = any(term in query.lower() for term in greeting_terms) and len(query.split()) < 4
    
    if is_greeting:
        return "Hello! I'm your CyberArk API assistant. How can I help you with the CyberArk API today?"
    
    # Step 1: Retrieve relevant documents using the best retrieval method
    # Using BERT reranking as it's shown good performance
    if debug:
        print(f"Retrieving documents for query: '{query}'")
    
    context_docs = get_bert_reordered_documents(query, debug=debug)
    context_text = "\n\n".join([doc.page_content for doc in context_docs])
    
    if debug:
        print(f"Retrieved {len(context_docs)} relevant documents")
    
    # Step 2: Generate dynamic prompts tailored to this specific query
    prompt_components = analyze_query_and_generate_prompts(query, debug=debug)
    
    # Step 3: Create chat prompt with the dynamically generated components
    system_message_prompt = SystemMessagePromptTemplate.from_template(
        prompt_components["system_prompt"]
    )
    
    human_message_prompt = HumanMessagePromptTemplate.from_template(
        prompt_components["user_message_template"]
    )
    
    chat_prompt = ChatPromptTemplate.from_messages([
        system_message_prompt,
        human_message_prompt
    ])
    
    # Step 4: Generate response with the customized prompt
    generation_chain = chat_prompt | llm
    
    # Add rate limiting
    time.sleep(0.5)
    
    response = generation_chain.invoke({
        "context": context_text,
        "question": query
    })
    
    # Extract the content from the response
    if hasattr(response, 'content'):
        response = response.content
    
    return response

# %%
# get_answer_with_dynamic_prompting("How to delete a policy?", debug=True)  # Example usage
# display(Markdown(get_answer_with_dynamic_prompting("How to delete a policy?", debug=True)))

# %% [markdown]
# # LLM JUDGE

# %% [markdown]
# ## Code Automation

# %% [markdown]
# ### Load the questions

# %%
import json


with open("/workspaces/RAG_BOT/Truths/FullQuestions_GPT.json") as f:
    questions = json.load(f)

print(f"Loaded {len(questions)} evaluation questions.")
# Out:
# Loaded 30 evaluation questions.

# %% [markdown]
# ### Create a Methods for LLM as Judge

# %%
import json
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from langchain_core.prompts import PromptTemplate

def evaluate_with_llm_judge(question, reference_answer, generated_answer):
    """
    Use the LLM to evaluate a generated answer against a reference answer.
    
    Args:
        question: The original question
        reference_answer: The ground truth answer
        generated_answer: The answer generated by the retrieval method
        
    Returns:
        JSON response with scores and feedback
    """
    # Create the prompt for the LLM judge
    judge_prompt = PromptTemplate.from_template("""
        You are an impartial judge evaluating the quality of answers provided by a chatbot based on a given reference answer. Your goal is to provide a comprehensive and fair assessment, focusing on accuracy, completeness, conciseness, clarity, adherence to instructions, and overall relevance.

            You will be given:

            1. **Question:** {QUESTION}
            2. **Reference Answer:** {REFERENCE_ANSWER}
            3. **Generated Answer:** {GENERATED_ANSWER}

            Your task is to compare the generated answer against the reference answer and assign scores based on the following criteria. Each score should be an integer from 1 to 5, where 1 is "Poor" and 5 is "Excellent".

            ---

            **Evaluation Criteria:**

            * **Accuracy (Score 1-5):**
                * How factually correct is the generated answer compared to the reference answer?
                * Does it contain any incorrect information or hallucinations?
                * Does it correctly interpret the intent of the question?
                * Score 1: Contains significant factual errors or hallucinations.
                * Score 2: Contains minor factual errors or some misinterpretations.
                * Score 3: Mostly accurate, but may have slight inaccuracies or omissions.
                * Score 4: Highly accurate, with no factual errors.
                * Score 5: Perfectly accurate and precise.

            * **Completeness (Score 1-5):**
                * Does the generated answer cover all the essential points and details present in the reference answer?
                * Does it omit any crucial information?
                * Score 1: Misses most essential information.
                * Score 2: Misses several key points.
                * Score 3: Covers most key points, but might omit some minor details.
                * Score 4: Covers almost all essential points comprehensively.
                * Score 5: Fully covers all essential points and details.

            * **Conciseness (Score 1-5):**
                * Is the generated answer to the point and free of unnecessary verbosity or repetition?
                * Does it provide relevant information without excessive preamble or redundant phrasing?
                * Score 1: Extremely verbose, repetitive, or contains irrelevant information.
                * Score 2: Noticeably verbose or somewhat repetitive.
                * Score 3: Generally concise, but could be slightly tighter.
                * Score 4: Concise and to the point.
                * Score 5: Perfectly concise and efficient.

            * **Clarity & Readability (Score 1-5):**
                * Is the generated answer easy to understand and well-structured?
                * Is the language clear, and is the formatting appropriate (e.g., use of bullet points, code blocks, bolding if applicable)?
                * Score 1: Difficult to understand, poorly structured, or confusing.
                * Score 2: Some parts are unclear or structure is lacking.
                * Score 3: Generally clear, but could be better organized or phrased.
                * Score 4: Clear, well-organized, and easy to read.
                * Score 5: Exceptionally clear, well-structured, and highly readable.

            * **Adherence to Instructions (Score 1-5):**
                * Does the generated answer follow any specific formatting rules or constraints (e.g., citation format, JSON structure if applicable for the chatbot's task, *not* inventing details, etc.)?
                * Does it correctly cite sources where required?
                * Score 1: Fails to follow most key instructions or violates major constraints.
                * Score 2: Fails to follow several instructions or has significant deviations.
                * Score 3: Follows most instructions, but has some minor deviations.
                * Score 4: Follows almost all instructions correctly.
                * Score 5: Perfectly adheres to all specified instructions.

            * **Relevance to Expected Answer (Score 1-5):**
                * How well does the generated answer match the *meaning*, *intent*, and *scope* of the reference answer?
                * Does it address the same core question in a way that is meaningfully equivalent?
                * Score 1: Entirely off-topic or unrelated to reference answer.
                * Score 2: Weak relevance, only partially addresses the expected content.
                * Score 3: Moderately relevant, but misses some key intent or scope.
                * Score 4: Strongly relevant, very close match to intent and scope.
                * Score 5: Perfectly relevant, fully equivalent in meaning and intent.

            ---

            **Output Format:**

            Your output must be a JSON object with the following structure:

            ```json
            {{
                "scores": {{
                    "accuracy": <score_1_5>,
                    "completeness": <score_1_5>,
                    "conciseness": <score_1_5>,
                    "clarity_readability": <score_1_5>,
                    "adherence_to_instructions": <score_1_5>,
                    "relevance_to_expected_answer": <score_1_5>
                }},
                "feedback": {{
                    "accuracy_notes": "<brief explanation for accuracy score, especially if not 5>",
                    "completeness_notes": "<brief explanation for completeness score, especially if not 5>",
                    "conciseness_notes": "<brief explanation for conciseness score, especially if not 5>",
                    "clarity_readability_notes": "<brief explanation for clarity & readability score, especially if not 5>",
                    "adherence_to_instructions_notes": "<brief explanation for adherence score, especially if not 5>",
                    "relevance_to_expected_answer_notes": "<brief explanation for relevance score, especially if not 5>",
                    "overall_summary": "<brief overall assessment of the generated answer, highlighting strengths and weaknesses>"
                }}
            }}
            ```
          
""")

    # Generate evaluation response
    generation_chain = judge_prompt | llm
    evaluation_response = generation_chain.invoke({
        "QUESTION": question,
        "REFERENCE_ANSWER": reference_answer,
        "GENERATED_ANSWER": generated_answer
    })
    
    # Extract content if using ChatOpenAI
    if hasattr(evaluation_response, 'content'):
        evaluation_response = evaluation_response.content

    # Parse the JSON response
    try:
        # Remove markdown code block markers if present
        evaluation_response = evaluation_response.replace("```json", "").replace("```", "").strip()
        evaluation_json = json.loads(evaluation_response)
        return evaluation_json
    except json.JSONDecodeError:
        print('----------- ERROR -------------')
        print(f"Error parsing JSON from LLM response. Raw response:\n{evaluation_response}")
        # Return a placeholder with error information
        return {
            "scores": {
                "accuracy": 0,
                "completeness": 0,
                "conciseness": 0,
                "clarity_readability": 0,
                "adherence_to_instructions": 0,
                "relevance_to_expected_answer": 0
            },
            "feedback": {
                "overall_summary": "Error parsing LLM response"
            },
            "raw_response": evaluation_response
        }

# %% [markdown]
# ### Run Parallel Evaluations for multiple methods

# %%
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm  # Import tqdm for Jupyter notebooks

def run_evaluation_parallel(questions, methods_dict, num_samples=None, max_workers=4):
    """
    Run evaluation on questions in parallel using multiple threads.
    
    Args:
        questions: List of question objects with category, question, answer, and difficulty
        methods_dict: Dictionary mapping method names to functions that take a question and return an answer
        num_samples: Optional number of questions to sample (for testing)
        max_workers: Maximum number of parallel workers (threads)
        
    Returns:
        DataFrame with all evaluation results
    """
    # Optionally sample a subset of questions
    if num_samples and num_samples < len(questions):
        import random
        sampled_questions = random.sample(questions, num_samples)
    else:
        sampled_questions = questions
    
    # Initialize a list to store all results (will be accessed by multiple threads)
    results = []
    
    # Create a lock to protect the results list during updates
    import threading
    results_lock = threading.Lock()
    
    # Function to process a single question (will be called in parallel)
    def process_question(question_data):
        i, q = question_data
        question_text = q["question"]
        reference_answer = q["answer"]
        category = q["category"]
        difficulty = q["difficulty"]
        
        question_results = []
        
        try:
            print(f"\nEvaluating question {i+1}/{len(sampled_questions)}")
            print(f"Category: {category}, Difficulty: {difficulty}")
            print(f"Question: {question_text}")
            
            # Get answers from all methods
            method_answers = {}
            
            # Generate answers from each method
            for method_name, method_func in methods_dict.items():
                print(f"\nGenerating answer with {method_name} for question {i+1}...")
                method_answers[method_name] = method_func(question_text)
            
            # Evaluate each method
            for method_name, answer in method_answers.items():
                print(f"\nEvaluating {method_name} answer for question {i+1}...")
                evaluation = evaluate_with_llm_judge(
                    question_text, reference_answer, answer
                )
                
                # Create a result dictionary
                result = {
                    "question_id": i,
                    "question": question_text,
                    "reference_answer": reference_answer,
                    "category": category,
                    "difficulty": difficulty,
                    "method": method_name,
                    "generated_answer": answer,
                    # Keep the original nested dictionaries for backward compatibility
                    "scores": evaluation.get("scores", {}),
                    "feedback": evaluation.get("feedback", {})
                }
                
                # Add individual score fields
                scores = evaluation.get("scores", {})
                for score_key in ["accuracy", "completeness", "conciseness", "clarity_readability", 
                                "adherence_to_instructions", "relevance_to_expected_answer"]:
                    result[f"score_{score_key}"] = scores.get(score_key, 0)
                
                # Add individual feedback fields
                feedback = evaluation.get("feedback", {})
                for feedback_key in ["accuracy_notes", "completeness_notes", "conciseness_notes", 
                                    "clarity_readability_notes", "adherence_to_instructions_notes", 
                                    "relevance_to_expected_answer_notes", "overall_summary"]:
                    result[f"feedback_{feedback_key}"] = feedback.get(feedback_key, "")
                
                question_results.append(result)
            
            # Save the results from this question
            with results_lock:
                results.extend(question_results)
                # Save intermediate results after each question
                interim_df = pd.DataFrame(results)
                interim_df.to_json("evaluation_results_interim.json", orient="records", indent=2)
                
            return True, i
            
        except Exception as e:
            print(f"Error processing question {i+1}: {e}")
            return False, i
    
    # Create a thread pool and process questions in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all questions to the executor
        future_to_question = {
            executor.submit(process_question, (i, q)): (i, q) 
            for i, q in enumerate(sampled_questions)
        }
        
        # Process results as they complete with a progress bar
        total = len(future_to_question)
        with tqdm(total=total, desc="Processing questions") as pbar:
            for future in concurrent.futures.as_completed(future_to_question):
                i, q = future_to_question[future]
                try:
                    success, question_id = future.result()
                    if success:
                        print(f"Question {question_id+1} completed successfully")
                    else:
                        print(f"Question {question_id+1} failed")
                except Exception as e:
                    print(f"Question {i+1} generated an exception: {e}")
                pbar.update(1)
    
    # Convert results to DataFrame for analysis
    results_df = pd.DataFrame(results)
    
    # Save the full results
    results_df.to_json("evaluation_results_final.json", orient="records", indent=2)
    
    return results_df

# %% [markdown]
# ### Run the Evaluation

# %%
results_df = run_evaluation_parallel(questions, 
                   {"Simple Ensemble Retriever": get_answer,
                    "Neighbourhood Expansion" : get_answer_using_neighbourhood,
                    "BERT-Reranking Retriever" : get_answer_using_bert_based_reordering,
                    "Recursive Retrieval-Generation with Self-Correction" : get_answer_with_recursive_generation,
                    "Dynamic Prompt Engineering Retrieval Method" : get_answer_with_dynamic_prompting}, max_workers=5)
# Out:
# Evaluating question 1/30
# Category: Basic endpoint recall, Difficulty: easy
# Question: Which specific endpoint is used to delete an application that has been added by an administrator?
#
# Generating answer with Simple Ensemble Retriever for question 1...
#
# Evaluating question 2/30
# Category: Basic endpoint recall, Difficulty: medium
# Question: What is the endpoint to get a list of all application templates available in the catalog, along with their categories?
#
# Generating answer with Simple Ensemble Retriever for question 2...
#
# Evaluating question 3/30
# Category: Basic endpoint recall, Difficulty: hard
# Question: Which specific endpoint is used to get all available data for the user portal, including applications and user information, in a single, efficient call?
#
# Generating answer with Simple Ensemble Retriever for question 3...
#
# Evaluating question 4/30
# Category: Request parameter identification, Difficulty: easy
# Question: When checking if a user is locked out by policy using the `/UserMgmt/IsUserLockedOutByPolicy` endpoint, what is the mandatory query parameter you must provide?
#
# Generating answer with Simple Ensemble Retriever for question 4...
#
# Evaluating question 5/30
# Category: Request parameter identification, Difficulty: medium
# Question: To retrieve all the applications a specific user has access to, which endpoint do you use and what specific parameter must be provided?
#
# Generating answer with Simple Ensemble Retriever for question 5...
# Processing questions:   0%|          | 0/30 [00:00<?, ?it/s]
# Generating answer with Neighbourhood Expansion for question 2...
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'What is the endpoint to get a list of all application templates available in the catalog, along with their categories?'
#
# Generating answer with Neighbourhood Expansion for question 3...
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 3 relevant documents for the query: 'Which specific endpoint is used to get all available data for the user portal, including applications and user information, in a single, efficient call?'
#
# Generating answer with Neighbourhood Expansion for question 1...
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 4 relevant documents for the query: 'Which specific endpoint is used to delete an application that has been added by an administrator?'
#
# Generating answer with Neighbourhood Expansion for question 5...
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 3 relevant documents for the query: 'To retrieve all the applications a specific user has access to, which endpoint do you use and what specific parameter must be provided?'
#
# Generating answer with BERT-Reranking Retriever for question 5...
#
# Generating answer with Neighbourhood Expansion for question 4...
#   Found 2 previous chunks and 2 next chunks
#
# Retrieved 5 relevant documents for the query: 'When checking if a user is locked out by policy using the `/UserMgmt/IsUserLockedOutByPolicy` endpoint, what is the mandatory query parameter you must provide?'
#
# Generating answer with BERT-Reranking Retriever for question 4...
#
# Generating answer with BERT-Reranking Retriever for question 2...
#
# Retrieved 3 relevant documents for the query: 'What is the endpoint to get a list of all application templates available in the catalog, along with their categories?'
#
# Generating answer with BERT-Reranking Retriever for question 1...
#
# Retrieved 5 relevant documents for the query: 'Which specific endpoint is used to delete an application that has been added by an administrator?'
#
# Retrieved 9 relevant documents for the query: 'When checking if a user is locked out by policy using the `/UserMgmt/IsUserLockedOutByPolicy` endpoint, what is the mandatory query parameter you must provide?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 4...
#
# Generating answer with BERT-Reranking Retriever for question 3...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 2...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 1...
#
# Retrieved 7 relevant documents for the query: 'To retrieve all the applications a specific user has access to, which endpoint do you use and what specific parameter must be provided?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 5...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
# No relevant docs were retrieved using the relevance score threshold 0.3
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='6b06e31c-b795-4d25-8cb7-1642abe3723b', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_008.txt', 'doc_name': 'UserManagement_endpoint_008', 'doc_index': 8, 'chunk_index': 6, 'total_chunks_in_doc': 18, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 7, 'next_doc_index': 9}, page_content='- **success** (boolean): Indicates if the API call was successful.\n- **Error** (object): Contains error message text on failure.\n  - **InvalidUserId** (string): Message indicating the user ID was not found.'), np.float32(-0.1293366)), (Document(id='130ed05e-699b-4720-953c-031e2579a5e2', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_013.txt', 'doc_name': 'UserManagement_endpoint_013', 'doc_index': 13, 'chunk_index': 3, 'total_chunks_in_doc': 9, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 12, 'next_doc_index': 14}, page_content="### Response Parameters\n- **Result (object)**: Contains detailed user information.\n  - **InEverybodyRole (boolean)**: Indicates if the user is in the Everybody role.\n  - **Description (string)**: A description of the user.\n  - **Name (string)**: The user's full name.\n  - **MobileNumber (string)**: The user's mobile phone number.\n  - **LastPasswordChangeDate (string)**: The date and time the user last changed their password.\n  - **OfficeNumber (string)**: The user's office phone number.\n  - **PictureUri (string)**: The file system path to the user's picture.\n  - **ReportsTo (string)**: The UUID of the user that this user reports to.\n  - **HomeNumber (string)**: The user's home phone number.\n  - **DisplayName (string)**: The user's display name.\n  - **Alias (string)**: The login suffix for the user.\n  - **State (string)**: The current state of the user (e.g., locked, enabled, expired).\n  - **PasswordNeverExpire (boolean)**: Indicates if the user's password is set to never expire."), np.float32(-0.14772546))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
# No relevant docs were retrieved using the relevance score threshold 0.3
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='130ed05e-699b-4720-953c-031e2579a5e2', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_013.txt', 'doc_name': 'UserManagement_endpoint_013', 'doc_index': 13, 'chunk_index': 3, 'total_chunks_in_doc': 9, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 12, 'next_doc_index': 14}, page_content="### Response Parameters\n- **Result (object)**: Contains detailed user information.\n  - **InEverybodyRole (boolean)**: Indicates if the user is in the Everybody role.\n  - **Description (string)**: A description of the user.\n  - **Name (string)**: The user's full name.\n  - **MobileNumber (string)**: The user's mobile phone number.\n  - **LastPasswordChangeDate (string)**: The date and time the user last changed their password.\n  - **OfficeNumber (string)**: The user's office phone number.\n  - **PictureUri (string)**: The file system path to the user's picture.\n  - **ReportsTo (string)**: The UUID of the user that this user reports to.\n  - **HomeNumber (string)**: The user's home phone number.\n  - **DisplayName (string)**: The user's display name.\n  - **Alias (string)**: The login suffix for the user.\n  - **State (string)**: The current state of the user (e.g., locked, enabled, expired).\n  - **PasswordNeverExpire (boolean)**: Indicates if the user's password is set to never expire."), np.float32(-0.15313745)), (Document(id='22421c7b-8a09-4dc4-bff8-ae80197e98a9', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_012.txt', 'doc_name': 'UserManagement_endpoint_012', 'doc_index': 12, 'chunk_index': 2, 'total_chunks_in_doc': 13, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 11, 'next_doc_index': 13}, page_content='- **Response Structure:**\n  - Status Code: 200 for a successful update.\n  - The response includes a result object with success status and error details if applicable.\n\n- **Error Handling:**\n  - The API will return specific error messages for invalid user IDs, invalid names, or if the ID is not provided.\n\n# Detailed Explanation of Available Data, Request and Response Parameters'), np.float32(-0.1596278))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 11 relevant documents for the query: 'Which specific endpoint is used to get all available data for the user portal, including applications and user information, in a single, efficient call?'
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 4...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 3...
# No relevant docs were retrieved using the relevance score threshold 0.3
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='130ed05e-699b-4720-953c-031e2579a5e2', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_013.txt', 'doc_name': 'UserManagement_endpoint_013', 'doc_index': 13, 'chunk_index': 3, 'total_chunks_in_doc': 9, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 12, 'next_doc_index': 14}, page_content="### Response Parameters\n- **Result (object)**: Contains detailed user information.\n  - **InEverybodyRole (boolean)**: Indicates if the user is in the Everybody role.\n  - **Description (string)**: A description of the user.\n  - **Name (string)**: The user's full name.\n  - **MobileNumber (string)**: The user's mobile phone number.\n  - **LastPasswordChangeDate (string)**: The date and time the user last changed their password.\n  - **OfficeNumber (string)**: The user's office phone number.\n  - **PictureUri (string)**: The file system path to the user's picture.\n  - **ReportsTo (string)**: The UUID of the user that this user reports to.\n  - **HomeNumber (string)**: The user's home phone number.\n  - **DisplayName (string)**: The user's display name.\n  - **Alias (string)**: The login suffix for the user.\n  - **State (string)**: The current state of the user (e.g., locked, enabled, expired).\n  - **PasswordNeverExpire (boolean)**: Indicates if the user's password is set to never expire."), np.float32(-0.15313745)), (Document(id='22421c7b-8a09-4dc4-bff8-ae80197e98a9', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_012.txt', 'doc_name': 'UserManagement_endpoint_012', 'doc_index': 12, 'chunk_index': 2, 'total_chunks_in_doc': 13, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 11, 'next_doc_index': 13}, page_content='- **Response Structure:**\n  - Status Code: 200 for a successful update.\n  - The response includes a result object with success status and error details if applicable.\n\n- **Error Handling:**\n  - The API will return specific error messages for invalid user IDs, invalid names, or if the ID is not provided.\n\n# Detailed Explanation of Available Data, Request and Response Parameters'), np.float32(-0.1596278))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 5...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 1...
#
# Evaluating Simple Ensemble Retriever answer for question 1...
#
# Evaluating Neighbourhood Expansion answer for question 1...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 2...
#
# Evaluating Simple Ensemble Retriever answer for question 4...
#
# Evaluating Neighbourhood Expansion answer for question 4...
#
# Evaluating BERT-Reranking Retriever answer for question 1...
#
# Evaluating Simple Ensemble Retriever answer for question 5...
#
# Evaluating BERT-Reranking Retriever answer for question 4...
#
# Evaluating Simple Ensemble Retriever answer for question 2...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 0 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 1...
#
# Evaluating Neighbourhood Expansion answer for question 5...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 1...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 4...
#
# Evaluating question 6/30Question 1 completed successfully
#
# Category: Request parameter identification, Difficulty: hard
# Question: When exempting a user from MFA requirements using `/CDirectoryService/ExemptUserFromMfa`, what are the required and optional parameters, and what is the default behavior of the optional parameter?
#
# Generating answer with Simple Ensemble Retriever for question 6...
#
# Evaluating Neighbourhood Expansion answer for question 2...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 3...
# No relevant docs were retrieved using the relevance score threshold 0.3
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='c6cbf7b1-1486-4975-9b02-ffc6a86a9446', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_016.txt', 'doc_name': 'UserManagement_endpoint_016', 'doc_index': 16, 'chunk_index': 6, 'total_chunks_in_doc': 19, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 15, 'next_doc_index': 17}, page_content="- **FullCount (integer)**: Total number of rows.\n        - **IsAggregate (boolean)**: Indicates if the result is aggregated.\n    - **InnerExceptions (string)**: Any inner exceptions received.\n    - **Message (string)**: Error message for failure responses.\n    - **success (boolean)**: Indicates success of the API call.\n    - **IsSoftError (boolean)**: Indicates if it's a soft error."), np.float32(-0.11201608)), (Document(id='51687e66-df49-42f5-bfdf-dfe365563e1b', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/ApplicationManagement_endpoint_008.txt', 'doc_name': 'ApplicationManagement_endpoint_008', 'doc_index': 8, 'chunk_index': 4, 'total_chunks_in_doc': 11, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 7, 'next_doc_index': 9}, page_content='### Response Parameters  \n- **Result** (object):  \n  - Description: Returns an object for a successful API call.  \n  - Nested properties:\n    - **ErrorID** (string): Error ID of any error during API execution.  \n    - **ErrorCode** (string): Error message of the occurred error.  \n    - **Exception** (string): If any exception has occurred.  \n    - **MessageID** (string): Message ID of the message.  \n    - **Result** (object): Application-related information returned.  \n    - **InnerExceptions** (string): Inner Exception, if any.  \n    - **Message** (string): Message if any exception occurs.  \n    - **success** (boolean): Indicates if the operation was successful (true or false).  \n    - **IsSoftError** (string): Indicates if the error is soft or not.'), np.float32(-0.15105283))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating Simple Ensemble Retriever answer for question 3...
#
# Generating answer with Neighbourhood Expansion for question 6...
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 4 relevant documents for the query: 'When exempting a user from MFA requirements using `/CDirectoryService/ExemptUserFromMfa`, what are the required and optional parameters, and what is the default behavior of the optional parameter?'
#
# Generating answer with BERT-Reranking Retriever for question 6...
#
# Retrieved 12 relevant documents for the query: 'When exempting a user from MFA requirements using `/CDirectoryService/ExemptUserFromMfa`, what are the required and optional parameters, and what is the default behavior of the optional parameter?'
#
# Evaluating BERT-Reranking Retriever answer for question 5...
#
# Evaluating BERT-Reranking Retriever answer for question 2...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 6...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 2...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 2...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 5...
#
# Evaluating Neighbourhood Expansion answer for question 3...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 4...
#
# Evaluating question 7/30Question 4 completed successfully
#
# Category: Request body schema understanding, Difficulty: easy
# Question: To create a new user using the `/CDirectoryService/CreateUser` endpoint, what are the minimum required fields in the JSON request body?
#
# Generating answer with Simple Ensemble Retriever for question 7...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 5...
#
# Generating answer with Neighbourhood Expansion for question 7...
#   Found 2 previous chunks and 0 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'To create a new user using the `/CDirectoryService/CreateUser` endpoint, what are the minimum required fields in the JSON request body?'
#
# Evaluating question 8/30Question 2 completed successfully
#
# Category: Request body schema understanding, Difficulty: medium
# Question: When using the `/SaasManage/SetApplicationPermissions` endpoint, what are the key properties required within the `Grants` object in the request body to define a permission?
#
# Generating answer with Simple Ensemble Retriever for question 8...
#
# Evaluating question 9/30Question 5 completed successfully
#
# Category: Request body schema understanding, Difficulty: hard
# Question: When adding a new custom attribute to the user schema via `/ExtData/UpdateSchema`, what is the correct structure of the request body and why is it necessary to include existing attributes?
#
# Generating answer with Simple Ensemble Retriever for question 9...
#
# Evaluating BERT-Reranking Retriever answer for question 3...
#
# Generating answer with Neighbourhood Expansion for question 8...
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 6 relevant documents for the query: 'When using the `/SaasManage/SetApplicationPermissions` endpoint, what are the key properties required within the `Grants` object in the request body to define a permission?'
#
# Generating answer with BERT-Reranking Retriever for question 7...
#
# Generating answer with BERT-Reranking Retriever for question 8...
#
# Retrieved 9 relevant documents for the query: 'When using the `/SaasManage/SetApplicationPermissions` endpoint, what are the key properties required within the `Grants` object in the request body to define a permission?'
#
# Generating answer with Neighbourhood Expansion for question 9...
#   Found 0 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Retrieved 8 relevant documents for the query: 'When adding a new custom attribute to the user schema via `/ExtData/UpdateSchema`, what is the correct structure of the request body and why is it necessary to include existing attributes?'
#
# Retrieved 11 relevant documents for the query: 'To create a new user using the `/CDirectoryService/CreateUser` endpoint, what are the minimum required fields in the JSON request body?'
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 3...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 8...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 7...
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 2 previous chunks and 0 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 3...
#
# Generating answer with BERT-Reranking Retriever for question 9...
#
# Evaluating question 10/30Question 3 completed successfully
#
# Category: Response schema comprehension, Difficulty: easy
# Question: After successfully cloning an application with `/SaasManage/CloneAnApplication`, what key piece of information is returned in the `Result` object of the response that identifies the new application?
#
# Generating answer with Simple Ensemble Retriever for question 10...
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='56fa5b7f-d5ee-45da-ad8f-765b591351e4', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_016.txt', 'doc_name': 'UserManagement_endpoint_016', 'doc_index': 16, 'chunk_index': 13, 'total_chunks_in_doc': 19, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 15, 'next_doc_index': 17}, page_content="* Description (string): It is the brief description of the column. Ex: 'Row Identifier (primary key)'\n                * Name (string): It is the name of the column.\n                * Format (string): Currently It is not applicable. By default it is null.\n                * TableName (string): It is the name of the table. By default it is null.\n                * DDName (string): It is the Data dictionary name of the column. Ex: 'ID'\n                * DDTitle (string): It is the Data dictionary title of the column. Ex: 'ID'\n                * Type (string): It is the numeric indicator of the type of data in the column. Ex: '12'\n                * IsHidden (boolean): specifies whether column is hidden or not. default: false\n                * Width (integer): Currently It is not applicable. By default it is 0.\n                * Title (string): Title of the column. Ex: 'ID'"), np.float32(-0.045562387)), (Document(id='690f66d7-3050-4696-bc86-dcbd752b698a', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/ApplicationManagement_endpoint_005.txt', 'doc_name': 'ApplicationManagement_endpoint_005', 'doc_index': 5, 'chunk_index': 18, 'total_chunks_in_doc': 20, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 4, 'next_doc_index': 6}, page_content="Nested properties:  \n                * _Value (string): Can be null or empty.  \n                * Enabled (boolean): It is set to true if rule is enabled else false.  \n                * _UniqueKey (string): It is the unique Id of the Authentication rule.  \n                * _Type (string): Ex: RowSet  \n            * Thumbprint (string): It is the thumbprint of Certificate for the application. Ex: C1222EFC3D1A54E47AD227C3CDAAE9F4804C82cd  \n            * _RowKey (string): It is the name or Unique Id of the Application. It is also known as App key. Ex: '52d1cec-63b7-4415-b4e0-facacb555d4e'"), np.float32(-0.097593665))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 6...
#
# Generating answer with Neighbourhood Expansion for question 10...
#   Found 2 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 8 relevant documents for the query: 'After successfully cloning an application with `/SaasManage/CloneAnApplication`, what key piece of information is returned in the `Result` object of the response that identifies the new application?'
#
# Generating answer with BERT-Reranking Retriever for question 10...
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='7bb896f7-abd9-4043-85a8-9e05e883468e', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/PolicyMangement_endpoint_007.txt', 'doc_name': 'PolicyMangement_endpoint_007', 'doc_index': 7, 'chunk_index': 3, 'total_chunks_in_doc': 5, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 6, 'next_doc_index': 8}, page_content='## Response Parameters  \n- **Result**  \n  - **Type:** Object  \n  - **Description:** Returns the maximum and minimum AAL on success or null on failure.  \n  - **Example Value:**  \n    ```json\n    {\n      "maxAAL": 3,\n      "minAAL": 1\n    }\n    ```\n\n- **Error**  \n  - **Type:** Object  \n  - **Description:** Contains an error message if the request fails, may be null.  \n  - **Example Value:**  \n    ```json\n    {\n      "message": "Invalid challenges parameter"\n    }\n    ```'), np.float32(-0.13880134)), (Document(id='2f2c475c-3a19-4e33-8b63-d4d7c596d65a', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/PolicyMangement_endpoint_006.txt', 'doc_name': 'PolicyMangement_endpoint_006', 'doc_index': 6, 'chunk_index': 0, 'total_chunks_in_doc': 5, 'is_first_chunk': True, 'is_last_chunk': False, 'prev_doc_index': 5, 'next_doc_index': 7}, page_content='# Overview  \nThe **Get Password Complexity Requirements** endpoint allows users to retrieve the password complexity requirements associated with a specific user. This is done through a POST request to the path **/Policy/GetPasswordComplexityRequirements**. The endpoint requires authentication via a bearer token to ensure secure access to user-specific data.\n\n# Key Search Terms  \n- Password complexity requirements  \n- User password policy  \n- Retrieve password settings  \n- API password rules  \n- User identifier password policy  \n- Security policy management  \n- Bearer token authentication  \n- POST request password complexity  \n- Policy Management API'), np.float32(-0.15097415))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 8...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 9 relevant documents for the query: 'When adding a new custom attribute to the user schema via `/ExtData/UpdateSchema`, what is the correct structure of the request body and why is it necessary to include existing attributes?'
#
# Retrieved 12 relevant documents for the query: 'After successfully cloning an application with `/SaasManage/CloneAnApplication`, what key piece of information is returned in the `Result` object of the response that identifies the new application?'
#
# Evaluating Simple Ensemble Retriever answer for question 6...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 7...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 10...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 9...
#
# Evaluating Neighbourhood Expansion answer for question 6...
#
# Evaluating BERT-Reranking Retriever answer for question 6...
#
# Evaluating Simple Ensemble Retriever answer for question 7...
#
# Evaluating Neighbourhood Expansion answer for question 7...
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Evaluating BERT-Reranking Retriever answer for question 7...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 7...
#
# Evaluating Simple Ensemble Retriever answer for question 8...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 7...
#
# Evaluating question 11/30Question 7 completed successfully
#
# Category: Response schema comprehension, Difficulty: medium
# Question: When you call `/UserMgmt/GetUsersRolesAndAdministrativeRights` for a user, what is the structure of the information returned in the response?
#
# Generating answer with Simple Ensemble Retriever for question 11...
#
# Generating answer with Neighbourhood Expansion for question 11...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 9 relevant documents for the query: 'When you call `/UserMgmt/GetUsersRolesAndAdministrativeRights` for a user, what is the structure of the information returned in the response?'
#
# Generating answer with BERT-Reranking Retriever for question 11...
#   Found 0 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 6...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 10...
#
# Evaluating Neighbourhood Expansion answer for question 8...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 9...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 6...
#
# Evaluating question 12/30Question 6 completed successfully
#
# Category: Response schema comprehension, Difficulty: hard
# Question: When retrieving an application's details with `/SaasManage/GetApplication`, what are at least five key fields you can expect in the `Result` object for a standard web application, and what do they represent?
#
# Generating answer with Simple Ensemble Retriever for question 12...
#
# Evaluating BERT-Reranking Retriever answer for question 8...
#
# Retrieved 11 relevant documents for the query: 'When you call `/UserMgmt/GetUsersRolesAndAdministrativeRights` for a user, what is the structure of the information returned in the response?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 11...
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 8...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 8...
#
# Generating answer with Neighbourhood Expansion for question 12...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 9 relevant documents for the query: 'When retrieving an application's details with `/SaasManage/GetApplication`, what are at least five key fields you can expect in the `Result` object for a standard web application, and what do they represent?'
#
# Evaluating Simple Ensemble Retriever answer for question 9...
#
# Evaluating Simple Ensemble Retriever answer for question 10...
#
# Evaluating Neighbourhood Expansion answer for question 10...
#
# Evaluating question 13/30Question 8 completed successfully
#
# Category: Authentication/security requirements, Difficulty: easy
# Question: What is the standard method of authentication required by the majority of the endpoints in the User Management, Application Management, and Policy Management APIs?
#
# Generating answer with Simple Ensemble Retriever for question 13...
#
# Evaluating Neighbourhood Expansion answer for question 9...
#
# Evaluating BERT-Reranking Retriever answer for question 10...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 10...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 11...
#
# Evaluating BERT-Reranking Retriever answer for question 9...
#
# Generating answer with BERT-Reranking Retriever for question 12...
#
# Generating answer with Neighbourhood Expansion for question 13...
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 6 relevant documents for the query: 'What is the standard method of authentication required by the majority of the endpoints in the User Management, Application Management, and Policy Management APIs?'
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 9...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 9...
#
# Generating answer with BERT-Reranking Retriever for question 13...
#
# Evaluating Simple Ensemble Retriever answer for question 11...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 10...
#
# Evaluating question 14/30Question 10 completed successfully
#
# Category: Authentication/security requirements, Difficulty: medium
# Question: Which endpoint in the User Management API is explicitly designed for unauthenticated use, and what is its purpose?
#
# Generating answer with Simple Ensemble Retriever for question 14...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 12 relevant documents for the query: 'When retrieving an application's details with `/SaasManage/GetApplication`, what are at least five key fields you can expect in the `Result` object for a standard web application, and what do they represent?'
#
# Retrieved 13 relevant documents for the query: 'What is the standard method of authentication required by the majority of the endpoints in the User Management, Application Management, and Policy Management APIs?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 13...
#
# Evaluating question 15/30Question 9 completed successfully
#
# Category: Authentication/security requirements, Difficulty: hard
# Question: Explain the purpose of the `RevStamp` field in the context of the `/Policy/SavePolicyBlock3` endpoint and why it is crucial for security and data integrity in a multi-administrator environment.
#
# Generating answer with Simple Ensemble Retriever for question 15...
#
# Evaluating Neighbourhood Expansion answer for question 11...
#
# Generating answer with Neighbourhood Expansion for question 14...
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 6 relevant documents for the query: 'Which endpoint in the User Management API is explicitly designed for unauthenticated use, and what is its purpose?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 12...
#
# Generating answer with Neighbourhood Expansion for question 15...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'Explain the purpose of the `RevStamp` field in the context of the `/Policy/SavePolicyBlock3` endpoint and why it is crucial for security and data integrity in a multi-administrator environment.'
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 1 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Evaluating BERT-Reranking Retriever answer for question 11...
#
# Generating answer with BERT-Reranking Retriever for question 14...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 11...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Generating answer with BERT-Reranking Retriever for question 15...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 13...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 16 relevant documents for the query: 'Which endpoint in the User Management API is explicitly designed for unauthenticated use, and what is its purpose?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 14...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 11...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 12...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 4 relevant documents for the query: 'Explain the purpose of the `RevStamp` field in the context of the `/Policy/SavePolicyBlock3` endpoint and why it is crucial for security and data integrity in a multi-administrator environment.'
#
# Evaluating question 16/30Question 11 completed successfully
#
# Category: Conditional/branching logic, Difficulty: easy
# Question: How does the `/AuthProfile/SaveProfile` endpoint differentiate between creating a new authentication profile and updating an existing one?
#
# Generating answer with Simple Ensemble Retriever for question 16...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 15...
#
# Evaluating Simple Ensemble Retriever answer for question 13...
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# Generating answer with Neighbourhood Expansion for question 16...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'How does the `/AuthProfile/SaveProfile` endpoint differentiate between creating a new authentication profile and updating an existing one?'
#
# Evaluating Simple Ensemble Retriever answer for question 12...
#
# Evaluating Neighbourhood Expansion answer for question 13...
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 14...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating BERT-Reranking Retriever answer for question 13...
#   Found 2 previous chunks and 1 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 15...
#
# Generating answer with BERT-Reranking Retriever for question 16...
#
# Evaluating Neighbourhood Expansion answer for question 12...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 13...
#
# Retrieved 7 relevant documents for the query: 'How does the `/AuthProfile/SaveProfile` endpoint differentiate between creating a new authentication profile and updating an existing one?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 16...
#
# Evaluating BERT-Reranking Retriever answer for question 12...
#
# Evaluating Simple Ensemble Retriever answer for question 15...
#
# Evaluating Neighbourhood Expansion answer for question 15...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 13...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 12...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 12...
#
# Evaluating Simple Ensemble Retriever answer for question 14...
#
# Evaluating Neighbourhood Expansion answer for question 14...
#
# Evaluating question 17/30Question 12 completed successfully
#
# Category: Conditional/branching logic, Difficulty: medium
# Question: What is the functional difference between the `/CDirectoryService/ChangeUserState` and `/CDirectoryService/SetUserState` endpoints for managing a user's status?
#
# Generating answer with Simple Ensemble Retriever for question 17...
#
# Generating answer with Neighbourhood Expansion for question 17...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'What is the functional difference between the `/CDirectoryService/ChangeUserState` and `/CDirectoryService/SetUserState` endpoints for managing a user's status?'
#
# Evaluating question 18/30Question 13 completed successfully
#
# Category: Conditional/branching logic, Difficulty: hard
# Question: When inviting users with `/UserMgmt/InviteUsers`, how can you conditionally send a single invitation to a group's email address instead of to every individual member of that group?
#
# Generating answer with Simple Ensemble Retriever for question 18...
#
# Generating answer with Neighbourhood Expansion for question 18...
#   Found 2 previous chunks and 2 next chunks
#
# Retrieved 5 relevant documents for the query: 'When inviting users with `/UserMgmt/InviteUsers`, how can you conditionally send a single invitation to a group's email address instead of to every individual member of that group?'
#
# Evaluating BERT-Reranking Retriever answer for question 15...
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with BERT-Reranking Retriever for question 18...
#
# Evaluating BERT-Reranking Retriever answer for question 14...
#
# Retrieved 6 relevant documents for the query: 'When inviting users with `/UserMgmt/InviteUsers`, how can you conditionally send a single invitation to a group's email address instead of to every individual member of that group?'
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 14...
#
# Generating answer with BERT-Reranking Retriever for question 17...
#
# Retrieved 11 relevant documents for the query: 'What is the functional difference between the `/CDirectoryService/ChangeUserState` and `/CDirectoryService/SetUserState` endpoints for managing a user's status?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 17...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 15...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 14...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 16...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 18...
#
# Evaluating question 19/30Question 14 completed successfully
#
# Category: Concurrency handling, Difficulty: easy
# Question: What field is essential for safely updating a policy to prevent conflicts when multiple administrators might be making changes?
#
# Generating answer with Simple Ensemble Retriever for question 19...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 15...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating question 20/30Question 15 completed successfully
#
# Category: Concurrency handling, Difficulty: medium
# Question: Why is it critical to first call `/Policy/GetPolicyBlock` before attempting to save changes to an existing policy with `/Policy/SavePolicyBlock3`?
#
# Generating answer with Simple Ensemble Retriever for question 20...
#
# Generating answer with Neighbourhood Expansion for question 19...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'What field is essential for safely updating a policy to prevent conflicts when multiple administrators might be making changes?'
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 18...
#
# Generating answer with Neighbourhood Expansion for question 20...
#   Found 2 previous chunks and 1 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'Why is it critical to first call `/Policy/GetPolicyBlock` before attempting to save changes to an existing policy with `/Policy/SavePolicyBlock3`?'
#
# Evaluating Simple Ensemble Retriever answer for question 18...
#
# Generating answer with BERT-Reranking Retriever for question 19...
#
# Evaluating Simple Ensemble Retriever answer for question 16...
#
# Evaluating Neighbourhood Expansion answer for question 18...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 8 relevant documents for the query: 'What field is essential for safely updating a policy to prevent conflicts when multiple administrators might be making changes?'
#
# Generating answer with BERT-Reranking Retriever for question 20...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 17...
#
# Evaluating Neighbourhood Expansion answer for question 16...
#
# Evaluating BERT-Reranking Retriever answer for question 18...
#
# Evaluating Simple Ensemble Retriever answer for question 17...
#
# Evaluating BERT-Reranking Retriever answer for question 16...
#
# Evaluating Neighbourhood Expansion answer for question 17...
#
# Evaluating BERT-Reranking Retriever answer for question 17...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 17...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 17...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 19...
#
# Retrieved 7 relevant documents for the query: 'Why is it critical to first call `/Policy/GetPolicyBlock` before attempting to save changes to an existing policy with `/Policy/SavePolicyBlock3`?'
#
# ...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 23...
#
# Evaluating BERT-Reranking Retriever answer for question 22...
#
# Generating answer with BERT-Reranking Retriever for question 24...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 22...
#
# Retrieved 10 relevant documents for the query: 'Explain the detailed workflow for adding a new custom attribute to the user schema and then setting a value for that new attribute for a specific user.'
#
# Generating answer with BERT-Reranking Retriever for question 25...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 26...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 22...
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# Retrieved 4 relevant documents for the query: 'When deleting multiple users with `/UserMgmt/RemoveUsers`, what is a critical precaution mentioned in the documentation that will cause the entire operation to fail?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 24...
#
# Evaluating question 27/30Question 22 completed successfully
#
# Category: Error handling / failure scenarios, Difficulty: hard
# Question: What happens if you try to delete a user via `/UserMgmt/RemoveUsers` who belongs to an external directory service like Active Directory, and what is the implication?
#
# Generating answer with Simple Ensemble Retriever for question 27...
#
# Generating answer with Neighbourhood Expansion for question 27...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'What happens if you try to delete a user via `/UserMgmt/RemoveUsers` who belongs to an external directory service like Active Directory, and what is the implication?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 25...
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Generating answer with BERT-Reranking Retriever for question 27...
#
# Retrieved 5 relevant documents for the query: 'What happens if you try to delete a user via `/UserMgmt/RemoveUsers` who belongs to an external directory service like Active Directory, and what is the implication?'
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 24...
#   Found 1 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Evaluating Simple Ensemble Retriever answer for question 23...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 25...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 27...
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating Neighbourhood Expansion answer for question 23...
#
# Evaluating Simple Ensemble Retriever answer for question 24...
#
# Evaluating Neighbourhood Expansion answer for question 24...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 26...
#
# Evaluating BERT-Reranking Retriever answer for question 24...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 24...
#
# Evaluating Simple Ensemble Retriever answer for question 25...
#
# Evaluating Neighbourhood Expansion answer for question 25...
#
# Evaluating BERT-Reranking Retriever answer for question 23...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating BERT-Reranking Retriever answer for question 25...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 25...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 23...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 24...
#
# Evaluating question 28/30Question 24 completed successfully
#
# Category: Cross-endpoint design understanding, Difficulty: easy
# Question: Which two endpoints from the Application Management API would you use to manage the lifecycle of an application tag, from creation to deletion?
#
# Generating answer with Simple Ensemble Retriever for question 28...
#
# Evaluating Simple Ensemble Retriever answer for question 26...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 25...
#
# Evaluating question 29/30Question 25 completed successfully
#
# Category: Cross-endpoint design understanding, Difficulty: medium
# Question: How do the endpoints `/ExtData/GetSchema` and `/ExtData/GetColumns` work together to provide a complete picture of a user's custom attributes?
#
# Generating answer with Simple Ensemble Retriever for question 29...
#
# Generating answer with Neighbourhood Expansion for question 29...
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#
# Retrieved 7 relevant documents for the query: 'How do the endpoints `/ExtData/GetSchema` and `/ExtData/GetColumns` work together to provide a complete picture of a user's custom attributes?'
#
# Evaluating Neighbourhood Expansion answer for question 26...
#
# Evaluating BERT-Reranking Retriever answer for question 26...
#
# Generating answer with BERT-Reranking Retriever for question 29...
#
# Retrieved 11 relevant documents for the query: 'How do the endpoints `/ExtData/GetSchema` and `/ExtData/GetColumns` work together to provide a complete picture of a user's custom attributes?'
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 29...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 26...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 26...
#
# Generating answer with Neighbourhood Expansion for question 28...
#   Found 0 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 6 relevant documents for the query: 'Which two endpoints from the Application Management API would you use to manage the lifecycle of an application tag, from creation to deletion?'
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating question 30/30Question 26 completed successfully
#
# Category: Cross-endpoint design understanding, Difficulty: hard
# Question: Explain how you would use a combination of endpoints from both User Management and Application Management to verify a user's access to a specific application and then retrieve that application's details.
#
# Generating answer with Simple Ensemble Retriever for question 30...
#
# Generating answer with BERT-Reranking Retriever for question 28...
#
# Retrieved 11 relevant documents for the query: 'Which two endpoints from the Application Management API would you use to manage the lifecycle of an application tag, from creation to deletion?'
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 23...
# Question 23 completed successfully
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 27...
#
# Generating answer with Neighbourhood Expansion for question 30...
#   Found 0 previous chunks and 2 next chunks
#
# Retrieved 3 relevant documents for the query: 'Explain how you would use a combination of endpoints from both User Management and Application Management to verify a user's access to a specific application and then retrieve that application's details.'
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='ca627f0a-6726-42ca-ac5c-ce1de466567a', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/UserManagement_endpoint_020.txt', 'doc_name': 'UserManagement_endpoint_020', 'doc_index': 20, 'chunk_index': 3, 'total_chunks_in_doc': 11, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 19, 'next_doc_index': 21}, page_content='- **Error Handling:**\n  - The response will include an `Error` object with specific messages for invalid table names or empty IDs.\n\n# Detailed Explanation of Available Data, Request and Response Parameters\n## Request Parameters\n- **ID** (string): \n  - Description: The unique identifier of the user whose attributes are being requested.\n  - Example: `"ID": "user123"`\n  \n- **IncludeNulls** (boolean): \n  - Description: A flag to indicate whether to include attributes with null values in the response.\n  - Example: `"IncludeNulls": false`\n  \n- **Table** (string): \n  - Description: The name of the table from which the attributes should be fetched.\n  - Example: `"Table": "UserAttributes"`'), np.float32(-0.0032807589)), (Document(id='b46ebda9-fce4-460f-9882-170108e40ef7', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/ApplicationManagement_endpoint_031.txt', 'doc_name': 'ApplicationManagement_endpoint_031', 'doc_index': 31, 'chunk_index': 4, 'total_chunks_in_doc': 10, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 30, 'next_doc_index': 32}, page_content="- **ErrorCode** (string): Error code if any error occurs, defaults to 'null'.\n- **InnerExceptions** (string): Additional exception details."), np.float32(-0.065346956))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
# No relevant docs were retrieved using the relevance score threshold 0.3
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 28...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 29...
# No relevant docs were retrieved using the relevance score threshold 0.3
# Evaluating Simple Ensemble Retriever answer for question 27...
#
# Generating answer with BERT-Reranking Retriever for question 30...
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1082: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='d9018a96-d5d7-480d-9f64-a1cd12b7b151', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/ApplicationManagement_endpoint_017.txt', 'doc_name': 'ApplicationManagement_endpoint_017', 'doc_index': 17, 'chunk_index': 14, 'total_chunks_in_doc': 22, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 16, 'next_doc_index': 18}, page_content='* Category (string): It is the Category which application belongs to. Following are the Categories available. Featured Analytics Collaboration Communication CRM Customer Service DevOps Education ERP Finance Government Health Care HR IT and Administration Marketing News and Research Other Product Management Productivity Project Management Sales Security Social Media Software Development Travel\n                * AdminTag (string): It is the admin tag provided for the Application. It is the same as the Category of the Application. Ex: Finance\n                * Name (string): It is the name of the Application.\n                * TemplateName (string): It is the template name of the Application. The templates can be internal as well as for external applications. Ex: Dropbox\n                * WebAppType (string): It is the type of web application. Like Portal, SAML, OpenIDConnect, OAuth etc.'), np.float32(0.034162045)), (Document(id='b1683ee5-7a9b-46e2-9388-6ebc06cb1e70', metadata={'source': '/workspaces/RAG_BOT/EnrichedData/ApplicationManagement_endpoint_005.txt', 'doc_name': 'ApplicationManagement_endpoint_005', 'doc_index': 5, 'chunk_index': 12, 'total_chunks_in_doc': 20, 'is_first_chunk': False, 'is_last_chunk': False, 'prev_doc_index': 4, 'next_doc_index': 6}, page_content="* Default (string): It is set to true if there any default mappings. Else false. By default, it is false.  \n                * Code (string): It is the code used to identify the language.  \n                * Description (string): It is the description about the application in the specified language.  \n                * Name (string): The Application's name in the specified language. Example: User Portal is 'Portail utilisateur' in french  \n            * CertificateSubjectName (string): This is the Application's subject name of the certificate. It is specific to the tenant. Ex: CN=ABC0000 Application Signing Certificate  \n            * Icon (string): It is the absolute path of the application's icon image. Ex: 'vfslow/lib/branding/Idaptive/userportal.png'  \n            * ACL (boolean): ACL(access control list) is a list of rules that specifies whether users have access to an application or any resource. It is true if the user has access to the Application. Else false."), np.float32(-0.016471863))]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.3
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#
# Evaluating Neighbourhood Expansion answer for question 27...
#
# Evaluating BERT-Reranking Retriever answer for question 27...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 28...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 27...
#
# Evaluating Simple Ensemble Retriever answer for question 29...
#
# Retrieved 10 relevant documents for the query: 'Explain how you would use a combination of endpoints from both User Management and Application Management to verify a user's access to a specific application and then retrieve that application's details.'
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 27...
# Question 27 completed successfully
#
# Evaluating Neighbourhood Expansion answer for question 29...
#
# Generating answer with Recursive Retrieval-Generation with Self-Correction for question 30...
#
# Evaluating Simple Ensemble Retriever answer for question 28...
#
# Evaluating BERT-Reranking Retriever answer for question 29...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 29...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 29...
#
# Evaluating Neighbourhood Expansion answer for question 28...
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 0 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
#   Found 2 previous chunks and 2 next chunks
#   Found 1 previous chunks and 2 next chunks
# Question 29 completed successfully
#
# Evaluating BERT-Reranking Retriever answer for question 28...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 28...
#
# Generating answer with Dynamic Prompt Engineering Retrieval Method for question 30...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 28...
# Question 28 completed successfully
#
# Evaluating Simple Ensemble Retriever answer for question 30...
#
# Evaluating Neighbourhood Expansion answer for question 30...
#
# Evaluating BERT-Reranking Retriever answer for question 30...
#
# Evaluating Recursive Retrieval-Generation with Self-Correction answer for question 30...
#
# Evaluating Dynamic Prompt Engineering Retrieval Method answer for question 30...
# Question 30 completed successfully

# %%
results_df
# Out:
#      question_id                                           question  \
# 0              0  Which specific endpoint is used to delete an a...
# 1              0  Which specific endpoint is used to delete an a...
# 2              0  Which specific endpoint is used to delete an a...
# 3              0  Which specific endpoint is used to delete an a...
# 4              0  Which specific endpoint is used to delete an a...
# ..           ...                                                ...
# 145           29  Explain how you would use a combination of end...
# 146           29  Explain how you would use a combination of end...
# 147           29  Explain how you would use a combination of end...
# 148           29  Explain how you would use a combination of end...
# 149           29  Explain how you would use a combination of end...
#
#                                       reference_answer  \
# 0    To delete an application, you must use the `PO...
# 1    To delete an application, you must use the `PO...
# 2    To delete an application, you must use the `PO...
# 3    To delete an application, you must use the `PO...
# 4    To delete an application, you must use the `PO...
# ..                                                 ...
# 145  First, you would use `POST /UPRest/GetResultan...
# 146  First, you would use `POST /UPRest/GetResultan...
# 147  First, you would use `POST /UPRest/GetResultan...
# 148  First, you would use `POST /UPRest/GetResultan...
# 149  First, you would use `POST /UPRest/GetResultan...
#
#                                 category difficulty  \
# 0                  Basic endpoint recall       easy
# 1                  Basic endpoint recall       easy
# 2                  Basic endpoint recall       easy
# 3                  Basic endpoint recall       easy
# 4                  Basic endpoint recall       easy
# ..                                   ...        ...
# 145  Cross-endpoint design understanding       hard
# 146  Cross-endpoint design understanding       hard
# 147  Cross-endpoint design understanding       hard
# 148  Cross-endpoint design understanding       hard
# 149  Cross-endpoint design understanding       hard
#
#                                                 method  \
# 0                            Simple Ensemble Retriever
# 1                              Neighbourhood Expansion
# 2                             BERT-Reranking Retriever
# 3    Recursive Retrieval-Generation with Self-Corre...
# 4          Dynamic Prompt Engineering Retrieval Method
# ..                                                 ...
# 145                          Simple Ensemble Retriever
# 146                            Neighbourhood Expansion
# 147                           BERT-Reranking Retriever
# 148  Recursive Retrieval-Generation with Self-Corre...
# 149        Dynamic Prompt Engineering Retrieval Method
#
#                                       generated_answer  \
# 0    The specific endpoint used to delete an applic...
# 1    To delete an application that has been added b...
# 2    The specific endpoint used to delete an applic...
# 3    To delete an application that has been added b...
# 4    To delete an application that has been added b...
# ..                                                 ...
# 145  To verify a user's access to a specific applic...
# 146  I'm specialized in CyberArk API documentation....
# 147  To verify a user's access to a specific applic...
# 148  To verify a user's access to a specific applic...
# 149  To verify a user's access to a specific applic...
#
#                                                 scores  \
# 0    {'accuracy': 4, 'completeness': 3, 'concisenes...
# 1    {'accuracy': 5, 'completeness': 5, 'concisenes...
# 2    {'accuracy': 5, 'completeness': 4, 'concisenes...
# 3    {'accuracy': 5, 'completeness': 5, 'concisenes...
# 4    {'accuracy': 4, 'completeness': 4, 'concisenes...
# ..                                                 ...
# 145  {'accuracy': 4, 'completeness': 4, 'concisenes...
# 146  {'accuracy': 1, 'completeness': 1, 'concisenes...
# 147  {'accuracy': 4, 'completeness': 4, 'concisenes...
# 148  {'accuracy': 4, 'completeness': 4, 'concisenes...
# 149  {'accuracy': 4, 'completeness': 4, 'concisenes...
#
#                                               feedback  score_accuracy  ...  \
# 0    {'accuracy_notes': 'The generated answer accur...               4  ...
# 1    {'accuracy_notes': 'The generated answer accur...               5  ...
# 2    {'accuracy_notes': 'The generated answer accur...               5  ...
# 3    {'accuracy_notes': 'The generated answer accur...               5  ...
# 4    {'accuracy_notes': 'The generated answer is mo...               4  ...
# ..                                                 ...             ...  ...
# 145  {'accuracy_notes': 'The generated answer is mo...               4  ...
# 146  {'accuracy_notes': 'The generated answer does ...               1  ...
# 147  {'accuracy_notes': 'The generated answer is mo...               4  ...
# 148  {'accuracy_notes': 'The generated answer is mo...               4  ...
# 149  {'accuracy_notes': 'The generated answer is mo...               4  ...
#
#      score_clarity_readability  score_adherence_to_instructions  \
# 0                            4                                4
# 1                            5                                5
# 2                            5                                5
# 3                            5                                5
# 4                            5                                5
# ..                         ...                              ...
# 145                          5                                5
# 146                          5                                5
# 147                          5                                5
# 148                          5                                5
# 149                          5                                5
#
#      score_relevance_to_expected_answer  \
# 0                                     4
# 1                                     5
# 2                                     5
# 3                                     5
# 4                                     5
# ..                                  ...
# 145                                   5
# 146                                   1
# 147                                   5
# 148                                   5
# 149                                   5
#
#                                feedback_accuracy_notes  \
# 0    The generated answer accurately identifies the...
# 1    The generated answer accurately reflects the e...
# 2    The generated answer accurately identifies the...
# 3    The generated answer accurately describes the ...
# 4    The generated answer is mostly accurate but in...
# ..                                                 ...
# 145  The generated answer is mostly accurate, but i...
# 146  The generated answer does not provide any rele...
# 147  The generated answer is mostly accurate but us...
# 148  The generated answer is mostly accurate, but i...
# 149  The generated answer is mostly accurate but us...
#
#                            feedback_completeness_notes  \
# 0    While the answer includes the endpoint and met...
# 1    All essential details from the reference answe...
# 2    The answer is mostly complete but omits the re...
# 3    It includes all essential details from the ref...
# 4    The answer covers most essential points, inclu...
# ..                                                 ...
# 145  The answer covers all essential steps and deta...
# 146  The answer fails to address the question at al...
# 147  The answer covers all essential points and det...
# 148  The answer covers all essential points but cou...
# 149  The answer covers all essential steps and deta...
#
#                             feedback_conciseness_notes  \
# 0    The answer is generally concise, providing nec...
# 1    The answer is mostly concise, but the inclusio...
# 2    The answer is concise and avoids unnecessary v...
# 3    While mostly concise, the inclusion of detaile...
# 4    The answer is generally concise, though it cou...
# ..                                                 ...
# 145  The answer is concise and avoids unnecessary v...
# 146  The answer is concise as it directly states a ...
# 147  The answer is concise and avoids unnecessary v...
# 148  The answer is generally concise, but there are...
# 149  The answer is concise and avoids unnecessary v...
#
#                     feedback_clarity_readability_notes  \
# 0    The structure is clear and easy to read, with ...
# 1    The answer is well-structured, using bullet po...
# 2    The answer is well-structured and easy to read...
# 3    The answer is well-structured, using headings ...
# 4    The answer is exceptionally clear and well-str...
# ..                                                 ...
# 145  The structure is clear, with well-defined step...
# 146  The answer is clear and easy to read, but it l...
# 147  The answer is exceptionally clear, well-struct...
# 148  The answer is exceptionally clear and well-str...
# 149  The structure is clear, with well-organized st...
#
#               feedback_adherence_to_instructions_notes  \
# 0    The answer follows the instructions well, but ...
# 1    The generated answer follows the instructions ...
# 2    The answer follows the required format and doe...
# 3    The answer follows the instructions perfectly,...
# 4    The generated answer follows the formatting an...
# ..                                                 ...
# 145  The answer adheres to the instructions well, p...
# 146  The answer adheres to the instruction of stati...
# 147  The generated answer follows all specified ins...
# 148  The generated answer perfectly adheres to the ...
# 149  The generated answer follows the instructions ...
#
#            feedback_relevance_to_expected_answer_notes  \
# 0    The answer is relevant and closely matches the...
# 1    The answer is fully relevant, addressing the c...
# 2    The answer is highly relevant and directly add...
# 3    The generated answer is fully relevant, addres...
# 4    The answer is highly relevant and addresses th...
# ..                                                 ...
# 145  The answer is highly relevant and addresses th...
# 146  The answer is entirely off-topic and does not ...
# 147  The answer is highly relevant and addresses th...
# 148  The answer is highly relevant and matches the ...
# 149  The answer is highly relevant and addresses th...
#
#                               feedback_overall_summary
# 0    The generated answer is mostly accurate and re...
# 1    The generated answer is comprehensive, accurat...
# 2    Overall, the generated answer is strong, with ...
# 3    The generated answer is comprehensive, accurat...
# 4    Overall, the generated answer is strong, with ...
# ..                                                 ...
# 145  Overall, the generated answer is strong in cla...
# 146  The generated answer is fundamentally flawed a...
# 147  Overall, the generated answer is strong, with ...
# 148  Overall, the generated answer is strong, with ...
# 149  Overall, the generated answer is strong in cla...
#
# [150 rows x 22 columns]

# %% [markdown]
# # PLOTS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set up the plotting style
plt.style.use('ggplot')
sns.set(font_scale=1.2)

# Create a radar chart to compare methods across all metrics
def plot_radar_chart(df):
    # Get the average scores for each method and metric
    metrics = ["score_accuracy", "score_completeness", "score_conciseness", 
               "score_clarity_readability", "score_adherence_to_instructions", 
               "score_relevance_to_expected_answer"]
    
    # Calculate mean scores by method
    avg_scores = df.groupby("method")[metrics].mean().reset_index()
    
    # Set up the radar chart
    methods = avg_scores["method"].tolist()
    metric_labels = [m.replace("score_", "") for m in metrics]
    
    # Number of metrics
    N = len(metrics)
    
    # Create angles for each metric
    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    angles += angles[:1]  # Close the loop
    
    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(polar=True))
    
    # Add each method as a separate line
    for i, method in enumerate(methods):
        values = avg_scores.loc[avg_scores["method"] == method, metrics].values.flatten().tolist()
        values += values[:1]  # Close the loop
        
        # Plot the line
        ax.plot(angles, values, linewidth=2, linestyle='solid', label=method)
        ax.fill(angles, values, alpha=0.1)
    
    # Fix axis to go in the right order and start at 12 o'clock
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    
    # Draw axis lines for each metric and label
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metric_labels)
    
    # Draw y-axis labels (0-5)
    ax.set_ylim(0, 5)
    ax.set_yticks([1, 2, 3, 4, 5])
    
    # Add legend
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    
    plt.title('Method Comparison Across All Metrics', size=15)
    plt.tight_layout()
    plt.show()

# Call the function with your results DataFrame
plot_radar_chart(results_df)

# Create a heatmap to show performance by category and difficulty
def plot_performance_heatmap(df):
    # Calculate average overall scores (mean of all score metrics)
    score_cols = [col for col in df.columns if col.startswith('score_')]
    df['avg_score'] = df[score_cols].mean(axis=1)
    
    # Pivot to create heatmap data
    heatmap_data = df.pivot_table(
        index=['category', 'difficulty'],
        columns='method',
        values='avg_score',
        aggfunc='mean'
    )
    
    # Sort by category and difficulty
    heatmap_data = heatmap_data.sort_index(level=[0, 1])
    
    # Create the heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(
        heatmap_data,
        annot=True,
        cmap='YlGnBu',
        linewidths=0.5,
        fmt='.2f',
        vmin=1,
        vmax=5,
        cbar_kws={'label': 'Average Score (1-5)'}
    )
    plt.title('Performance by Category and Difficulty', size=15)
    plt.tight_layout()
    plt.show()
    
    return heatmap_data

# Generate the heatmap
performance_by_category = plot_performance_heatmap(results_df)

# Create bar charts to compare methods by difficulty
def plot_difficulty_comparison(df):
    # Get average scores by method and difficulty
    difficulty_scores = df.groupby(['method', 'difficulty'])[
        [col for col in df.columns if col.startswith('score_')]
    ].mean().reset_index()
    
    # Calculate overall average score
    difficulty_scores['overall_score'] = difficulty_scores[
        [col for col in difficulty_scores.columns if col.startswith('score_')]
    ].mean(axis=1)
    
    # Plot
    plt.figure(figsize=(12, 6))
    chart = sns.barplot(
        x='difficulty',
        y='overall_score',
        hue='method',
        data=difficulty_scores,
        palette='Set2'
    )
    
    # Add value labels
    for p in chart.patches:
        chart.annotate(
            f"{p.get_height():.2f}",
            (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center',
            va='bottom',
            fontsize=10
        )
    
    plt.title('Performance by Difficulty Level', size=15)
    plt.xlabel('Difficulty')
    plt.ylabel('Average Score (1-5)')
    plt.ylim(0, 5.5)
    plt.tight_layout()
    plt.show()

# Generate the difficulty comparison
plot_difficulty_comparison(results_df)

# %% [markdown]
# ### 1. Individual Score Metrics by Difficulty

# %%
# Create individual score comparison by difficulty
def plot_individual_scores_by_difficulty(df):
    """Create bar plots for each score metric across difficulty levels"""
    score_metrics = [col for col in df.columns if col.startswith('score_')]
    
    # Set up a figure with subplots for each metric
    fig, axes = plt.subplots(3, 2, figsize=(18, 15))
    axes = axes.flatten()
    
    for i, metric in enumerate(score_metrics):
        # Create grouped bar plot
        sns.barplot(
            x='difficulty', 
            y=metric, 
            hue='method',
            data=df, 
            ax=axes[i],
            palette='Set2'
        )
        
        # Customize subplot
        metric_name = metric.replace('score_', '').replace('_', ' ').title()
        axes[i].set_title(f'{metric_name} by Difficulty', fontsize=14)
        axes[i].set_xlabel('Difficulty', fontsize=12)
        axes[i].set_ylabel(f'{metric_name} Score (1-5)', fontsize=12)
        axes[i].set_ylim(0, 5.5)
        
        # Add data labels
        for p in axes[i].patches:
            height = p.get_height()
            if not np.isnan(height):
                axes[i].annotate(
                    f"{height:.2f}", 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', 
                    va='bottom', 
                    fontsize=9
                )
    
    plt.tight_layout()
    plt.show()

# Call the function
plot_individual_scores_by_difficulty(results_df)

# %% [markdown]
# ### 2. Method Performance by Category

# %%
def plot_method_by_category(df):
    """Visualize method performance by category"""
    # Calculate average scores by method and category
    score_cols = [col for col in df.columns if col.startswith('score_')]
    if 'avg_score' not in df.columns:
        df['avg_score'] = df[score_cols].mean(axis=1)
    
    # Create a grouped bar plot for category performance
    plt.figure(figsize=(14, 8))
    category_plot = sns.barplot(
        x='category',
        y='avg_score',
        hue='method',
        data=df,
        palette='Set2'
    )
    
    # Add data labels
    for p in category_plot.patches:
        height = p.get_height()
        if not np.isnan(height):
            category_plot.annotate(
                f"{height:.2f}", 
                (p.get_x() + p.get_width() / 2., height),
                ha='center', 
                va='bottom', 
                fontsize=10
            )
    
    plt.title('Average Performance by Category', fontsize=16)
    plt.xlabel('Category', fontsize=14)
    plt.ylabel('Average Score (1-5)', fontsize=14)
    plt.ylim(0, 5.5)
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Method')
    plt.tight_layout()
    plt.show()
    
    # Create a heatmap showing the difference between methods by category
    # Pivot to get a category x method matrix
    pivot_df = df.pivot_table(
        index='category',
        columns='method',
        values='avg_score',
        aggfunc='mean'
    )
    
    # Calculate the difference between methods
    methods = pivot_df.columns.tolist()
    if len(methods) == 2:  # If we have exactly two methods
        pivot_df['difference'] = pivot_df[methods[0]] - pivot_df[methods[1]]
        
        # Plot the differences
        plt.figure(figsize=(10, 6))
        bars = pivot_df['difference'].sort_values().plot(kind='barh', color=pivot_df['difference'].apply(
            lambda x: 'green' if x > 0 else 'red'
        ))
        
        # Add data labels
        for i, v in enumerate(pivot_df['difference'].sort_values()):
            bars.text(v + (0.1 if v >= 0 else -0.1), 
                    i, 
                    f"{v:.2f}", 
                    ha='left' if v >= 0 else 'right',
                    va='center')
        
        plt.title(f'Score Difference by Category ({methods[0]} - {methods[1]})', fontsize=16)
        plt.xlabel('Score Difference', fontsize=14)
        plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)
        plt.tight_layout()
        plt.show()

# Call the function
plot_method_by_category(results_df)

# %% [markdown]
# ### 3. Score Metric Heatmaps by Category

# %%
def plot_metric_heatmaps_by_category(df):
    """Create consolidated heatmaps for all metrics by category and method"""
    score_cols = [col for col in df.columns if col.startswith('score_')]
    
    # Create a single figure with subplots
    fig, axes = plt.subplots(3, 2, figsize=(20, 15))
    axes = axes.flatten()
    
    for i, metric in enumerate(score_cols):
        metric_name = metric.replace('score_', '').replace('_', ' ').title()
        
        # Create pivot table
        heat_pivot = df.pivot_table(
            index='category',
            columns='method',
            values=metric,
            aggfunc='mean'
        )
        
        # Plot heatmap in the corresponding subplot
        sns.heatmap(
            heat_pivot,
            annot=True,
            cmap='YlGnBu',
            fmt='.2f',
            vmin=1,
            vmax=5,
            cbar_kws={'label': f'Score (1-5)'},
            ax=axes[i]
        )
        
        axes[i].set_title(f'{metric_name}', fontsize=14)
        axes[i].set_ylabel('Category')
        axes[i].set_xlabel('Method')
    
    plt.tight_layout()
    plt.show()

# Call the function
plot_metric_heatmaps_by_category(results_df)
# Out:
# /tmp/ipykernel_4059/3164951106.py:36: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### 4. Score Distribution Analysis

# %%
def analyze_score_distributions(df):
    """Analyze the distribution of scores across methods"""
    # Melt the dataframe to get scores in a single column
    score_cols = [col for col in df.columns if col.startswith('score_')]
    melted_df = df.melt(
        id_vars=['method', 'difficulty', 'category', 'question_id'],
        value_vars=score_cols,
        var_name='metric',
        value_name='score'
    )
    
    # Clean up metric names for display
    melted_df['metric'] = melted_df['metric'].apply(
        lambda x: x.replace('score_', '').replace('_', ' ').title()
    )
    
    # Create boxplot of scores by metric and method
    plt.figure(figsize=(14, 8))
    sns.boxplot(
        x='metric',
        y='score',
        hue='method',
        data=melted_df,
        palette='Set2'
    )
    
    plt.title('Distribution of Scores by Metric and Method', fontsize=16)
    plt.xlabel('Evaluation Metric', fontsize=14)
    plt.ylabel('Score (1-5)', fontsize=14)
    plt.ylim(0, 5.5)
    plt.xticks(rotation=30, ha='right')
    plt.legend(title='Method')
    plt.tight_layout()
    plt.show()

# Call the function
analyze_score_distributions(results_df)

# %% [markdown]
# ### 5. Method Win Analysis

# %%
def analyze_method_wins(df):
    """Analyze which method performs better by question"""
    # Calculate average score if not already present
    score_cols = [col for col in df.columns if col.startswith('score_')]
    if 'avg_score' not in df.columns:
        df['avg_score'] = df[score_cols].mean(axis=1)
    
    # Identify winning method by question
    win_data = []
    for qid in df['question_id'].unique():
        question_df = df[df['question_id'] == qid]
        winner = question_df.loc[question_df['avg_score'].idxmax(), 'method']
        category = question_df['category'].iloc[0]
        difficulty = question_df['difficulty'].iloc[0]
        win_data.append({
            'question_id': qid,
            'winner': winner,
            'category': category,
            'difficulty': difficulty
        })
    
    win_df = pd.DataFrame(win_data)
    
    # Win analysis by category
    cat_wins = pd.crosstab(win_df['category'], win_df['winner'])
    
    plt.figure(figsize=(40, 40))
    cat_wins.plot(kind='bar')
    plt.title('Method Wins by Category', fontsize=10)
    plt.xlabel('Category', fontsize=10)
    plt.ylabel('Number of Wins', fontsize=10)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.legend(title='Method', fontsize=10, title_fontsize=12)
    plt.tight_layout()
    plt.show()

# Call the function
analyze_method_wins(results_df)

# %% [markdown]
# ### 6. Most Common Feedback Analysis

# %%
import re
from collections import Counter
from IPython.display import display, Markdown

def extract_common_feedback_by_method(df):
    """Print the most recurring feedback for each metric, separated by method"""
    feedback_cols = [col for col in df.columns if col.startswith('feedback_') and col != 'feedback_overall_summary']
    methods = df['method'].unique()
    
    for method in methods:
        print(f"\n## Method: {method}")
        print("=" * (len(method) + 10))
        
        # Filter dataframe for just this method
        method_df = df[df['method'] == method]
        
        for feedback_col in feedback_cols:
            metric_name = feedback_col.replace('feedback_', '').replace('_notes', '').replace('_', ' ').title()
            
            # Get all feedback for this metric from this method
            feedback_texts = method_df[feedback_col].dropna().tolist()
            
            # Count identical feedback phrases
            feedback_counter = Counter(feedback_texts)
            
            # Get the most common feedback
            most_common = feedback_counter.most_common(1)
            
            if most_common and most_common[0][0] and not pd.isna(most_common[0][0]):
                feedback_text, count = most_common[0]
                print(f"\n### {metric_name}:")
                print(f"  Most common feedback ({count} occurrences): \"{feedback_text}\"")
    
    print("\n")

# Execute the function
extract_common_feedback_by_method(results_df)
# Out:
# ## Method: Simple Ensemble Retriever
# ===================================
#
# ### Accuracy:
#   Most common feedback (1 occurrences): "The generated answer accurately identifies the endpoint and HTTP method, but it lacks the specific requirement for the application's _RowKey in the request body, which is crucial for accuracy."
#
# ### Completeness:
#   Most common feedback (1 occurrences): "While the answer includes the endpoint and method, it omits the requirement for the _RowKey in the request body, which is a key detail from the reference answer."
#
# ### Conciseness:
#   Most common feedback (3 occurrences): "The answer is concise and directly addresses the question without unnecessary information."
#
# ### Clarity Readability:
#   Most common feedback (2 occurrences): "The answer is well-structured and easy to read, with appropriate use of bullet points and clear language."
#
# ### Adherence To Instructions:
#   Most common feedback (1 occurrences): "The answer follows the instructions well, but it could improve by including all necessary details from the reference answer."
#
# ### Relevance To Expected Answer:
#   Most common feedback (5 occurrences): "The answer is highly relevant and addresses the core question effectively, matching the intent and scope of the reference answer."
#
# ## Method: Neighbourhood Expansion
# =================================
#
# ### Accuracy:
#   Most common feedback (3 occurrences): "The generated answer does not provide any factual information related to the question and instead states a lack of knowledge."
#
# ### Completeness:
#   Most common feedback (2 occurrences): "The answer fails to address the question at all, missing all essential information."
#
# ### Conciseness:
#   Most common feedback (2 occurrences): "The answer is concise as it directly states a lack of information without unnecessary elaboration."
#
# ### Clarity Readability:
#   Most common feedback (3 occurrences): "The answer is clear and well-structured, making it easy to read and understand."
#
# ### Adherence To Instructions:
#   Most common feedback (3 occurrences): "The answer adheres to the instruction of not inventing details, but it fails to provide any relevant information."
#
# ### Relevance To Expected Answer:
#   Most common feedback (3 occurrences): "The answer is highly relevant and addresses the core question effectively."
#
# ## Method: BERT-Reranking Retriever
# ==================================
#
# ### Accuracy:
#   Most common feedback (2 occurrences): "The generated answer does not provide any factual information about the endpoints, which is a significant error."
#
# ### Completeness:
#   Most common feedback (1 occurrences): "The answer is mostly complete but omits the requirement for the application's '_RowKey' in the request body, which is a crucial detail."
#
# ### Conciseness:
#   Most common feedback (1 occurrences): "The answer is concise and avoids unnecessary verbosity, though it could be slightly tighter by removing the phrase 'from the admin portal' as it is implied."
#
# ### Clarity Readability:
#   Most common feedback (4 occurrences): "The answer is clear and well-structured, making it easy to read and understand."
#
# ### Adherence To Instructions:
#   Most common feedback (1 occurrences): "The answer follows the required format and does not deviate from the instructions."
#
# ### Relevance To Expected Answer:
#   Most common feedback (5 occurrences): "The answer is highly relevant and addresses the core question effectively, matching the intent and scope of the reference answer."
#
# ## Method: Recursive Retrieval-Generation with Self-Correction
# =============================================================
#
# ### Accuracy:
#   Most common feedback (1 occurrences): "The generated answer accurately describes the endpoint and its requirements without any factual errors."
#
# ### Completeness:
#   Most common feedback (1 occurrences): "It includes all essential details from the reference answer, such as the endpoint, method, request body, and error handling."
#
# ### Conciseness:
#   Most common feedback (2 occurrences): "The answer is mostly concise, but could be slightly tighter by reducing some redundancy in phrasing."
#
# ### Clarity Readability:
#   Most common feedback (3 occurrences): "The answer is clear and well-structured, making it easy to understand."
#
# ### Adherence To Instructions:
#   Most common feedback (1 occurrences): "The answer follows the instructions perfectly, providing the required information in the specified format."
#
# ### Relevance To Expected Answer:
#   Most common feedback (4 occurrences): "The answer is highly relevant and directly addresses the question, matching the intent and scope of the reference answer."
#
# ## Method: Dynamic Prompt Engineering Retrieval Method
# =====================================================
#
# ### Accuracy:
#   Most common feedback (1 occurrences): "The generated answer is mostly accurate but introduces 'applicationId' instead of '_RowKey', which is a minor deviation from the reference answer."
#
# ### Completeness:
#   Most common feedback (1 occurrences): "The answer covers most essential points, including the endpoint and its purpose, but it could have explicitly mentioned the requirement of '_RowKey' as stated in the reference."
#
# ### Conciseness:
#   Most common feedback (2 occurrences): "While mostly concise, the answer could be slightly tighter by reducing some redundancy in explanations."
#
# ### Clarity Readability:
#   Most common feedback (5 occurrences): "The answer is well-structured, easy to read, and uses appropriate formatting, making it clear and understandable."
#
# ### Adherence To Instructions:
#   Most common feedback (1 occurrences): "The generated answer follows the formatting and structure well, adhering to the instructions provided."
#
# ### Relevance To Expected Answer:
#   Most common feedback (3 occurrences): "The answer is highly relevant and addresses the core question effectively, matching the intent and scope of the reference answer."

# %% [markdown]
# ### 7. Correlation Between Score Metrics

# %%
def analyze_score_correlations(df):
    """Analyze correlations between different score metrics"""
    score_cols = [col for col in df.columns if col.startswith('score_')]
    
    plt.figure(figsize=(12, 10))
    correlation = df[score_cols].corr()
    sns.heatmap(
        correlation,
        annot=True,
        cmap='coolwarm',
        fmt='.2f',
        vmin=-1,
        vmax=1
    )
    plt.title('Correlation Between Score Metrics', fontsize=16)
    plt.tight_layout()
    plt.show()

# Call the function
analyze_score_correlations(results_df)
